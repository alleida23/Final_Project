# %% [markdown]
# # BOOK RECOMMENDER

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn import cluster, datasets
from sklearn.cluster import KMeans

import random
from IPython.display import Markdown, display

# %%
gr_data = pd.read_csv('./2. Clean_df/gr_data_FOR_CLUSTERING.csv')
gr_data = gr_data.drop(['Unnamed: 0'],axis=1)
display(gr_data.head(3),gr_data.shape)
# Out:
#                                        title                 series  \
# 0                           The Hunger Games       The Hunger Games
# 1  Harry Potter and the Order of the Phoenix           Harry Potter
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
#
#             author                                        description  \
# 0  Suzanne Collins  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1     J.K. Rowling  There is a door at the end of a silent corrido...
# 2       Harper Lee  The unforgettable novel of a childhood in a sl...
#
#   language    pages         isbn book_format  publish_year  \
# 0  English  200-300  9.78044E+12   Hardcover          2008
# 1  English  700-800  9.78044E+12   Paperback          2004
# 2  English  200-300        1E+13   Paperback          2006
#
#    first_publish_year  ...  \
# 0                2008  ...
# 1                2003  ...
# 2                1960  ...
#
#   West Australian Young Readers' Book Award (WAYRBA) for Younger Readers   \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    William Allen White Children's Book Award   \
# 0                                           0
# 1                                           0
# 2                                           0
#
#    William C. Morris YA Debut Award Nominee   \
# 0                                          0
# 1                                          0
# 2                                          0
#
#    Women's Prize for Fiction Nominee   \
# 0                                   0
# 1                                   0
# 2                                   0
#
#    Women's Prize for Fiction Nominee for Longlist   \
# 0                                                0
# 1                                                0
# 2                                                0
#
#    World Fantasy Award Nominee for Best Novel   \
# 0                                            0
# 1                                            0
# 2                                            0
#
#    World Fantasy Award for Best Novel   Zilveren Griffel   \
# 0                                    0                  0
# 1                                    0                  0
# 2                                    0                  0
#
#    الجائزة العالمية للرواية العربية (أي باف) / International Prize for Arabic Fiction (IPAF) Nominee   \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    pages2
# 0   374.0
# 1   870.0
# 2   324.0
#
# [3 rows x 863 columns]
# (48540, 863)

# %% [markdown]
# ## Function

# %%
def book_recommender(book_searched, gr_data):
    
    import unidecode
    import random
    from IPython.display import display, Markdown
    from sklearn.preprocessing import StandardScaler
    from sklearn.metrics.pairwise import cosine_similarity
    from sklearn import cluster, datasets
    from sklearn.cluster import KMeans

    """Treated book input"""
    
    # Get rid of accents in user input
    book_searched = unidecode.unidecode(book_searched)
    
    # Normalize book_searched to lowercase and strip leading/trailing whitespace
    book_searched = book_searched.lower().strip()

    # Check if the book is in gr_data:
    book_matches = gr_data[gr_data['title'].str.lower().str.contains(book_searched)]
    
    # If book searches IS IN gr_data
    if not book_matches.empty:
        
        """ Most similar book from same cluster """
        
        # Select numerical features
        X_features = gr_data.select_dtypes(np.number)
        
        # Scaling Data
        scaler = StandardScaler()
        X_prep = scaler.fit_transform(X_features)
        
        # KMeans : 13 clusters
        kmeans = KMeans(n_init='auto', n_clusters=13, random_state=1234)
        kmeans.fit(X_prep)
        
        # Finding the index of the selected book:
        gr_data['title'] = gr_data['title'].str.lower().str.strip()
        gr_index = gr_data.index[gr_data['title'] == book_searched]
        
        book_index = gr_index[0]
        
        if len(book_index) == 0:
            print(f"No matching song found for {book_searched}")
            return None, gr_data
            
        # Predicting cluster for the selected song:
        book_cluster = kmeans.predict(X_prep[book_index].reshape(1, -1))[0]
        
        # Selecting a random song from the same cluster:
        cluster_books = gr_data[kmeans.labels_ == book_cluster]
        recommended_book = cluster_books.sample(n=1)

        # Get the top recommended book
        #recommended_book = book_matches[book_matches['title'].str.lower().str.strip() != book_searched].sample(1)
        
        # Display the recommendation message
        message = random.choice([
            f"Based on your selection of '**{book_searched.capitalize()}**', we recommend the *hot* book '**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}**.'",
            f"Looks like you've got great taste in books! We recommend the *sizzling* read '**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}** based on your choice of '**{book_searched.capitalize()}**'.",
            f"You've hit the jackpot with your choice of '**{book_searched.capitalize()}**'! Our recommendation for you is the *hyped* book '**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}**.",
            f"Based on your selection of '**{book_searched.capitalize()}**', we think you'll love the *popular* book '**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}**'.",
            f"Based on your selection of '**{book_searched.capitalize()}**', we suggest the *trending* novel '**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}**.'",
            f"Based on your selection of '**{book_searched.capitalize()}**', you might also like the *bestselling* book '**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}**.'",
            f"Looks like you're a big fan of **{book_searched.capitalize()}**! Our recommendation algorithm thinks you'll enjoy the hilarious and heartwarming **{recommended_book['title'].iloc[0]}** by **{recommended_book['author'].iloc[0]}**. Get ready to laugh and cry!",
            f"Oh joy, another person searching for **{book_searched.capitalize()}**. Haven't we had enough of that book already? But since you insist, our recommendation algorithm suggests the timeless classic **{recommended_book['title'].iloc[0]}** by **{recommended_book['author'].iloc[0]}**. Just kidding, it's probably just more of the same.",
            f"Based on your selection of '**{book_searched.capitalize()}**', we recommend the *hot* book '**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}**."
                    ])
        display(Markdown(message))
        # display the recommended book description
        display(Markdown(f"**Description:**\n{recommended_book['description'].iloc[0]}\n"))
        # display the GoodReaders community rating
        display(Markdown(f"**GoodReaders rating:** {recommended_book['rating'].iloc[0]:.2f}/5"))

    
    # If book not in gr_data, ask user if they meant the correct title by the author
    else:
        # Get a list of books with matching authors
        author_matches = gr_data[gr_data['author'].str.lower().str.strip() == book_searched]
        # If there are no matches by author, ask the user to search again
        if author_matches.empty:
            message = f"Sorry, we couldn't find any books by that title or author. Please try again."
            display(Markdown(message))
        # If there are matches by author, ask the user to select the correct book
        else:
            message = f"Did you mean any of these books by **{book_searched.capitalize()}**?\n"
            for i, match in enumerate(author_matches['title']):
                message += f"{i+1}. {match}\n"
            display(Markdown(message))
            while True:
                choice = input("Enter the number of the selected book or enter 0 to search again: ")
                if not choice.isdigit() or int(choice) < 0 or int(choice) > len(author_matches):
                    print("Invalid choice. Please enter a number between 1 and", len(author_matches),"or enter 0 to search again.")
                elif choice == '0':
                    break
                else:
                    selected_book = author_matches.iloc[int(choice)-1]['title']
                    message = f"Great, you selected {selected_book}. Let's get the book's details!"
                    display(Markdown(message))
                    book_info = get_book_info(selected_book, author_matches.iloc[int(choice)-1]['author'])
                    display_book_info(book_info)
                    break
    return None

# %%
book_searched = input("Enter the name of the book you are interested in: ")
book = book_recommender(book_searched, gr_data)
# Out:
# Enter the name of the book you are interested in: the hunger games
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/w7/7cfd14hn02g0d126w5q47rqw0000gn/T/ipykernel_3162/1330659395.py in <module>
#       1 book_searched = input("Enter the name of the book you are interested in: ")
# ----> 2 book = book_recommender(book_searched, gr_data)
#
# /var/folders/w7/7cfd14hn02g0d126w5q47rqw0000gn/T/ipykernel_3162/3119054430.py in book_recommender(book_searched, gr_data)
#      42         book_index = gr_index[0]
#      43
# ---> 44         if len(book_index) == 0:
#      45             print(f"No matching song found for {book_searched}")
#      46             return None, gr_data
#
# TypeError: object of type 'numpy.int64' has no len()

# %%
def book_recommender(book_searched, gr_data):
    
    import unidecode
    import random
    from IPython.display import display, Markdown

    # Get rid of accents in user input
    book_searched = unidecode.unidecode(book_searched)
    
    # Normalize book_searched to lowercase and strip leading/trailing whitespace
    book_searched = book_searched.lower().strip()

    # Check if the book is in gr_data:
    if book_searched in gr_data['title'].str.lower().str.strip().values:
        # Get the top recommended book
        recommended_book = gr_data[gr_data['title'].str.lower().str.strip() != book_searched].sample(1)
        # Display the recommendation message
        message = random.choice([
            f"Based on your selection of '**{book_searched.capitalize()}**', we recommend the *hot* song '**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}**.",
            f"You might enjoy '**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}** as a follow-up to '**{book_searched.capitalize()}**'.",
            f"After enjoying '**{book_searched.capitalize()}**', you might want to check out '**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}**.",
            f"'**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}** might be up your alley after reading '**{book_searched.capitalize()}**'.",
            f"Looking for your next read after '**{book_searched.capitalize()}**'? Check out '**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}**."
        ])
        display(Markdown(message))
    
    # If book not in gr_data, ask user if they meant the correct title by the author
    else:
        # Get a list of books with matching authors
        author_matches = gr_data[gr_data['author'].str.lower().str.strip() == book_searched]
        # If there are no matches by author, ask the user to search again
        if author_matches.empty:
            message = f"Sorry, we couldn't find any books by that title or author. Please try again."
            display(Markdown(message))
        # If there are matches by author, ask the user to select the correct book
        else:
            message = f"Did you mean any of these books by **{book_searched.capitalize()}**?\n"
            for i, match in enumerate(author_matches['title']):
                message += f"{i+1}. {match}\n"
            display(Markdown(message))
            while True:
                choice = input("Enter the number of the selected book or enter 0 to search again: ")
                if not choice.isdigit() or int(choice) < 0 or int(choice) > len(author_matches):
                    print("Invalid choice. Please enter a number between 1 and", len(author_matches), "or enter 0 to search again.")
                else:
                    choice = int(choice)
                    if choice == 0:
                        break
                    else:
                        recommended_book = author_matches.iloc[choice-1]
                        message = random.choice([
                            f"Based on your selection of '**{book_searched.capitalize()}**', we recommend the *hot* book '**{recommended_book['title']}**' by **{recommended_book['author']}**.",
                            f"Based on your selection of '**{book_searched.capitalize()}**', we think you'll love the *popular* book '**{recommended_book['title']}**' by **{recommended_book['author']}**.",
                            f"Based on your selection of '**{book_searched.capitalize()}**', we suggest the *trending* novel '**{recommended_book['title']}**' by **{recommended_book['author']}**.'",
                            f"Based on your selection of '**{book_searched.capitalize()}**', you might also like the *bestselling* book '**{recommended_book['title']}**' by **{recommended_book['author']}**.'"
                        ])
                        display(Markdown(message))
                        break

# %%
book_searched = input("Enter the name of the book or author you are interested in: ")
book = book_recommender(book_searched, gr_data)
# Out:
# Enter the name of the book or author you are interested in: harry potter
# Yeehaw, looks like our book-eating monster hasn't gotten its hands on '**Harry potter**' one yet! We'll try to add it soon, partner!

# %%
book_searched = input("Enter the name of the book or author you are interested in: ")
book = book_recommender(book_searched, gr_data)
# Out:
# Enter the name of the book or author you are interested in: harry potter
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/w7/7cfd14hn02g0d126w5q47rqw0000gn/T/ipykernel_2915/1961422651.py in <module>
#       1 book_searched = input("Enter the name of the book or author you are interested in: ")
# ----> 2 book = book_recommender(book_searched, gr_data)
#
# /var/folders/w7/7cfd14hn02g0d126w5q47rqw0000gn/T/ipykernel_2915/251600073.py in book_recommender(book_searched, gr_data)
#      32         # KMeans : 13 clusters
#      33         kmeans = KMeans(n_clusters=13, random_state=1234)
# ---> 34         kmeans.fit(X_prep)
#      35
#      36         # Finding the index of the selected book:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1415         self._validate_params()
#    1416
# -> 1417         X = self._validate_data(
#    1418             X,
#    1419             accept_sparse="csr",
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     563             raise ValueError("Validation should be done on X, y or both.")
#     564         elif not no_val_X and no_val_y:
# --> 565             X = check_array(X, input_name="X", **check_params)
#     566             out = X
#     567         elif no_val_X and not no_val_y:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     919
#     920         if force_all_finite:
# --> 921             _assert_all_finite(
#     922                 array,
#     923                 input_name=input_name,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     159                 "#estimators-that-handle-nan-values"
#     160             )
# --> 161         raise ValueError(msg_err)
#     162
#     163
#
# ValueError: Input X contains NaN.
# KMeans does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
import random
from IPython.display import display, Markdown

def book_recommender(book_searched, gr_data):
    # Normalize book_searched to lowercase and strip leading/trailing whitespace
    book_searched = book_searched.lower().strip()

    # Check if the book is in gr_data:
    if book_searched in gr_data['title'].str.lower().str.strip().values:
        # Get the top recommended book
        recommended_book = gr_data[gr_data['title'].str.lower().str.strip() != book_searched].sample(1)
        # Display the recommendation message
        message = random.choice([
            f"Based on your selection of '**{book_searched.capitalize()}**', we recommend the *hot* song '**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}**.",
            f"You might enjoy '**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}** as a follow-up to '**{book_searched.capitalize()}**'.",
            f"After enjoying '**{book_searched.capitalize()}**', you might want to check out '**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}**.",
            f"'**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}** might be up your alley after reading '**{book_searched.capitalize()}**'.",
            f"Looking for your next read after '**{book_searched.capitalize()}**'? Check out '**{recommended_book['title'].iloc[0]}**' by **{recommended_book['author'].iloc[0]}**."
        ])
        display(Markdown(message))
    
    # If book not in gr_data:
    else:
        messages = [
            f"Yeehaw, looks like our book-eating monster hasn't gotten its hands on '**{book_searched.capitalize()}**' one yet! We'll try to add it soon, partner!",
            f"Sorry, pardner, but we don't seem to have '**{book_searched.capitalize()}**' in our catalog yet. We'll rustle up a copy as soon as we can!",
            f"Alas, '**{book_searched.capitalize()}**' is not yet among the books in our corral. We'll round it up soon, friend!",
            f"Oh my stars and garters, we don't have '**{book_searched.capitalize()}**' in our library yet! We'll add it as soon as we can!",
            f"Bless your heart, we don't have '**{book_searched.capitalize()}**' in our collection yet. But don't you fret, we'll lasso a copy soon!"
        ]
        message = random.choice(messages)
        display(Markdown(message))

# %%
def book_recommender(book_searched, gr_data):
    # Get a list of books with matching titles
    title_matches = gr_data[gr_data['title'].str.lower().str.strip().str.contains(book_searched.lower().strip())]
    
    # If there are no matches by title, get a list of books with matching authors
    if title_matches.empty:
        author_matches = gr_data[gr_data['author'].str.lower().str.strip().str.contains(book_searched.lower().strip())]
        # If there are no matches by author, ask the user to search again
        if author_matches.empty:
            message = f"Sorry, we couldn't find any books by that title or author. Please try again."
            display(Markdown(message))
            return None
        # If there are matches by author, ask the user to select the correct book
        else:
            message = f"We found multiple books by different titles and authors that match '{book_searched}':\n"
            for i, match in enumerate(author_matches['title']):
                message += f"{i+1}. {match} by {author_matches.iloc[i]['author']}\n"
            message += "Please enter the number of the book you are looking for:"
            display(Markdown(message))
            while True:
                choice = input("Enter the number of the selected book or enter 0 to search again: ")
                if not choice.isdigit() or int(choice) < 0 or int(choice) > len(author_matches):
                    print("Invalid choice. Please enter a number between 1 and", len(author_matches), "or enter 0 to search again.")
                elif choice == '0':
                    break
                else:
                    selected_book = author_matches.iloc[int(choice)-1]['title']
                    message = f"Great, you selected '{selected_book}' by {author_matches.iloc[int(choice)-1]['author']}. Let's get the book's details!"
                    display(Markdown(message))
                    book_info = get_book_info(selected_book, author_matches.iloc[int(choice)-1]['author'])
                    display_book_info(book_info)
                    break
            return None
    # If there are matches by title, ask the user to select the correct book
    else:
        message = f"We found multiple books by different authors that match '{book_searched}':\n"
        for i, match in enumerate(title_matches['title']):
            message += f"{i+1}. {match} by {title_matches.iloc[i]['author']}\n"
        message += "Please enter the number of the book you are looking for:"
        display(Markdown(message))
        while True:
            choice = input("Enter the number of the selected book or enter 0 to search again: ")
            if not choice.isdigit() or int(choice) < 0 or int(choice) > len(title_matches):
                print("Invalid choice. Please enter a number between 1 and", len(title_matches), "or enter 0 to search again.")
            elif choice == '0':
                break
            else:
                selected_book = title_matches.iloc[int(choice)-1]['title']
                message = f"Great, you selected '{selected_book}' by {title_matches.iloc[int(choice)-1]['author']}. Let's get the book's details!"
                display(Markdown(message))
                #book_info = get_book_info(selected_book, title_matches.iloc[int(choice)-1]['author'])
                #display_book_info(book_info)
                break
        return None

# %%
book_searched = input("Enter the name of the book or author you are interested in: ")
book = book_recommender(book_searched, gr_data)
# Out:
# Enter the name of the book or author you are interested in: harry
# We found multiple books by different authors that match 'harry':
# 1. Harry Potter and the Order of the Phoenix by J.K. Rowling, Mary GrandPré (Illustrator)
# 2. Harry Potter and the Sorcerer's Stone by J.K. Rowling, Mary GrandPré (Illustrator)
# 3. Harry Potter and the Deathly Hallows by J.K. Rowling
# 4. Harry Potter and the Prisoner of Azkaban by J.K. Rowling, Mary GrandPré (Illustrator)
# 5. Harry Potter and the Goblet of Fire by J.K. Rowling, Mary GrandPré (Illustrator)
# 6. Harry Potter and the Half-Blood Prince by J.K. Rowling
# 7. Harry Potter and the Chamber of Secrets by J.K. Rowling, Mary GrandPré (Illustrator)
# 8. Harry Potter Series Box Set by J.K. Rowling
# 9. Harry Potter and the Cursed Child: Parts One and Two by John Tiffany (Adaptation), Jack Thorne, J.K. Rowling
# 10. The Harry Potter Collection 1-4 by J.K. Rowling, Mary GrandPré (Illustrator)
# 11. La Vérité sur l'affaire Harry Quebert by Joël Dicker
# 12. Harry Potter Collection by J.K. Rowling
# 13. Harry Potter and the Methods of Rationality by Eliezer Yudkowsky (Goodreads Author)
# 14. The First Fifteen Lives of Harry August by Claire North
# 15. Harry Potter and the Order of the Phoenix (Harry Potter, #5, Part 1) by J.K. Rowling
# 16. The Harry Potter trilogy by J.K. Rowling
# 17. Harry Potter Boxed Set, Books 1-5 (Harry Potter, #1-5) by J.K. Rowling, Mary GrandPré (Illustrator)
# 18. Harry Potter: Film Wizardry by Brian Sibley
# 19. Harry Potter Schoolbooks Box Set: Two Classic Books from the Library of Hogwarts School of Witchcraft and Wizardry by J.K. Rowling
# 20. See You at Harry's by Jo Knowles (Goodreads Author)
# 21. Selections from Harry Potter and the Order of the Phoenix: Piano Solos by John Williams, Nicholas Hooper
# 22. Harry Potter: A History of Magic by British Library, J.K. Rowling, Julian Harrison (Introduction), Julia Eccleshare (Contributor), Roger Highfield (Contributor), Anna Pavord (Contributor), Lucy Mangan (Contributor), Tim Peake (Contributor), more…
# 23. Chasing Harry Winston by Lauren Weisberger
# 24. Harry Potter: The Prequel by J.K. Rowling
# 25. When Grandmama Fell Off the Boat: The Best of Harry Graham by Harry Graham
# 26. Until Harry by L.A. Casey (Goodreads Author)
# 27. New Harry Hole Thriller: The Thirst Free Ebook Sampler by Jo Nesbø (Goodreads Author)
# 28. Becoming Justice Blackmun: Harry Blackmun's Supreme Court Journey by Linda Greenhouse
# 29. Uncle Harry's Stories: Looking Back Blackly and Proudly Growing Up in America by Harry R. Irving (Goodreads Author)
# 30. Harry Potter and the Chamber of Secrets: Sheet Music for Flute with C.D by John Williams
# 31. Love at Goon Park: Harry Harlow and the Science of Affection by Deborah Blum
# 32. Harry Potter: A Pop-Up Book: Based on the Film Phenomenon by Andrew Williamson (Illustrations), Andrew Williamson (Illustrator)
# 33. The Unofficial Harry Potter Cookbook: From Cauldron Cakes to Knickerbocker Glory--More Than 150 Magical Recipes for Wizards and Non-Wizards Alike by Dinah Bucholz
# 34. The End of Harry Potter? by David Langford
# 35. The Magical Worlds Of Harry Potter: A Treasury Of Myths, Legends And Fascinating Facts by David Colbert (Goodreads Author)
# 36. Horrible Harry Moves up to the Third Grade by Suzy Kline, Frank Remkiewicz (Illustrations)
# 37. Handsome Harry by James Carlos Blake
# 38. Harry Styles and the New York Apocalypse by G.B. Hope (Goodreads Author)
# 39. Harry Hill's TV Burp Book by Harry Hill
# Please enter the number of the book you are looking for:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/w7/7cfd14hn02g0d126w5q47rqw0000gn/T/ipykernel_2915/1961422651.py in <module>
#       1 book_searched = input("Enter the name of the book or author you are interested in: ")
# ----> 2 book = book_recommender(book_searched, gr_data)
#
# /var/folders/w7/7cfd14hn02g0d126w5q47rqw0000gn/T/ipykernel_2915/3796495166.py in book_recommender(book_searched, gr_data)
#      40         display(Markdown(message))
#      41         while True:
# ---> 42             choice = input("Enter the number of the selected book or enter 0 to search again: ")
#      43             if not choice.isdigit() or int(choice) < 0 or int(choice) > len(title_matches):
#      44                 print("Invalid choice. Please enter a number between 1 and", len(title_matches), "or enter 0 to search again.")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
gr_data[['title','author']]
# Out:
#                                            title  \
# 0                               The Hunger Games
# 1      Harry Potter and the Order of the Phoenix
# 2                          To Kill a Mockingbird
# 3                            Pride and Prejudice
# 4                                       Twilight
# ...                                          ...
# 52473                                  Fractured
# 52474                                    Anasazi
# 52475                                     Marked
# 52476                                Wayward Son
# 52477                        Daughter of Helaman
#
#                                                   author
# 0                                        Suzanne Collins
# 1              J.K. Rowling, Mary GrandPré (Illustrator)
# 2                                             Harper Lee
# 3              Jane Austen, Anna Quindlen (Introduction)
# 4                                        Stephenie Meyer
# ...                                                  ...
# 52473                   Cheri Schmidt (Goodreads Author)
# 52474                                      Emma Michaels
# 52475                  Kim Richardson (Goodreads Author)
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...
# 52477                    Misty Moncur (Goodreads Author)
#
# [52478 rows x 2 columns]

# %%
# Accents

from unidecode import unidecode

# Apply unidecode to the title and author columns
gr_data['title'] = gr_data['title'].apply(unidecode)
gr_data['author'] = gr_data['author'].apply(unidecode)

# Now you can use the unaccented title and author columns for searching
book_matches = gr_data[gr_data['title'].str.lower().str.strip() == book_searched.lower().strip()]
author_matches = gr_data[gr_data['author'].str.lower().str.strip() == book_searched.lower().strip()]
