# %% [markdown]
# # Open Library
#
# https://openlibrary.org/dev/docs/api/books

# %%
# Libraries
import pandas as pd
import requests
import json
import time
import random

# %% [markdown]
# #### Random search by ISBN

# %%
# Specify the ISBN or Open Library ID of the book you want to retrieve
book_identifier = '9780439554930'

# Make a GET request to the Open Library API
response = requests.get(f'https://openlibrary.org/api/books?bibkeys=ISBN:{book_identifier}&format=json&jscmd=data')

# Parse the JSON response
book_data = response.json()

# Extract the title of the book from the response
book_title = book_data[f'ISBN:{book_identifier}']['title']

print(book_title)
# Out:
# Harry Potter and the Sorcerers Stone

# %%
# Different keys and data (random search)

# %%
book_data['ISBN:9780439554930'].keys()
# Out:
# dict_keys(['url', 'key', 'title', 'authors', 'identifiers', 'publishers', 'publish_date', 'subjects', 'subject_places', 'subject_people', 'excerpts', 'links', 'cover'])

# %%
book_data['ISBN:9780439554930']['title'] #title
# Out:
# 'Harry Potter and the Sorcerers Stone'

# %%
book_data['ISBN:9780439554930']['authors'][0]['name'] #name
# Out:
# 'J. K. Rowling'

# %%
book_data['ISBN:9780439554930']['identifiers']['isbn_13'][0] # ISBN 13
# Out:
# '9780439554930'

# %%
book_data['ISBN:9780439554930']['publish_date'] # Publish date
# Out:
# '2003'

# %%
#book_data['ISBN:9780439554930']['subjects']

# %%
book_data[f'ISBN:{book_identifier}']['subject_places']
# Out:
# [{'name': 'England', 'url': 'https://openlibrary.org/subjects/place:england'},
#  {'name': 'Hogwarts School of Witchcraft and Wizardry',
#   'url': 'https://openlibrary.org/subjects/place:hogwarts_school_of_witchcraft_and_wizardry'},
#  {'name': '4 Privet Drive',
#   'url': 'https://openlibrary.org/subjects/place:4_privet_drive'},
#  {'name': 'Diagon Alley',
#   'url': 'https://openlibrary.org/subjects/place:diagon_alley'},
#  {'name': 'Leaky Cauldron',
#   'url': 'https://openlibrary.org/subjects/place:leaky_cauldron'},
#  {'name': 'Gringotts Wizarding Bank',
#   'url': 'https://openlibrary.org/subjects/place:gringotts_wizarding_bank'},
#  {'name': 'Forbidden Forest',
#   'url': 'https://openlibrary.org/subjects/place:forbidden_forest'},
#  {'name': "King's Cross Station",
#   'url': "https://openlibrary.org/subjects/place:king's_cross_station"},
#  {'name': 'Platform Nine and Three-quarters',
#   'url': 'https://openlibrary.org/subjects/place:platform_nine_and_three-quarters'}]

# %% [markdown]
# #### Keys for all 'fiction' books

# %%
# Set url and query parameters for the API request
base_url = 'http://openlibrary.org/search.json'

params = {'q': 'fiction'}

# Make the API request
response = requests.get(base_url, params=params)
response

data = json.loads(response.text)
data
# Out:
# {'numFound': 1450694,
#  'start': 0,
#  'numFoundExact': True,
#  'docs': [{'key': '/works/OL21886356W',
#    'type': 'work',
#    'seed': ['/books/OL29847262M',
#     '/books/OL30319264M',
#     '/books/OL30325696M',
#     '/books/OL30357773M',
#     '/books/OL34214743M',
#     '/books/OL30334381M',
#     '/books/OL29956311M',
#     '/books/OL34211537M',
#     '/books/OL34263415M',
#     '/books/OL30008154M',
#     '/books/OL30337819M',
#     '/books/OL34130662M',
#     '/books/OL36147924M',
#     '/books/OL36151761M',
#     '/books/OL36602364M',
#     '/books/OL36590163M',
#     '/books/OL36854011M',
#     '/books/OL36872062M',
#     '/books/OL36165308M',
#     '/books/OL36060391M',
#     '/books/OL35052869M',
#     '/books/OL34289223M',
#     '/books/OL37603261M',
#     '/books/OL36170472M',
#     '/books/OL34244325M',
#     '/books/OL36461059M',
#     '/books/OL36984634M',
#     '/books/OL36855851M',
#     '/books/OL34283889M',
#     '/books/OL37646738M',
#     '/books/OL36969369M',
#     '/books/OL36994828M',
#     '/books/OL36470239M',
#     '/books/OL36599644M',
#     '/books/OL37525379M',
#     '/books/OL35239931M',
#     '/books/OL35001276M',
#     '/books/OL36073803M',
#     '/books/OL36998686M',
#     '/books/OL36590736M',
#     '/books/OL35022080M',
#     '/books/OL34303132M',
#     '/books/OL37730828M',
#     '/books/OL36474750M',
#     '/books/OL36119205M',
#     '/books/OL36455586M',
#     '/books/OL36954128M',
#     '/books/OL34329780M',
#     '/books/OL34222038M',
#     '/books/OL34324365M',
#     '/books/OL35237900M',
#     '/books/OL36587716M',
#     '/books/OL37517519M',
#     '/books/OL37525711M',
#     '/books/OL36956539M',
#     '/books/OL36900734M',
#     '/books/OL36609165M',
#     '/books/OL36990941M',
#     '/books/OL36964115M',
#     '/books/OL37497970M',
#     '/books/OL34256306M',
#     '/books/OL35165474M',
#     '/books/OL36504273M',
#     '/books/OL36599600M',
#     '/books/OL35029854M',
#     '/books/OL36598862M',
#     '/books/OL37518756M',
#     '/books/OL34343187M',
#     '/books/OL34347869M',
#     '/books/OL36072149M',
#     '/books/OL36094880M',
#     '/books/OL35018642M',
#     '/books/OL34301333M',
#     '/books/OL36045932M',
#     '/books/OL36489357M',
#     '/books/OL34121886M',
#     '/books/OL37502832M',
#     '/books/OL37501597M',
#     '/books/OL34259687M',
#     '/books/OL37566944M',
#     '/books/OL34332105M',
#     '/books/OL36089769M',
#     '/books/OL34340358M',
#     '/books/OL37529724M',
#     '/books/OL34210315M',
#     '/books/OL36505987M',
#     '/books/OL36898698M',
#     '/books/OL35024007M',
#     '/books/OL36368116M',
#     '/books/OL34327707M',
#     '/books/OL37634283M',
#     '/books/OL36990453M',
#     '/books/OL36893750M',
#     '/books/OL37527466M',
#     '/books/OL36471150M',
#     '/books/OL36987537M',
#     '/books/OL36580128M',
#     '/books/OL36992904M',
#     '/books/OL34335003M',
#     '/books/OL36996498M',
#     '/books/OL36171279M',
#     '/books/OL36606338M',
#     '/books/OL34234886M',
#     '/books/OL37699304M',
#     '/works/OL21886356W',
#     '/authors/OL408063A'],
#    'title': 'Herland Illustrated',
#    'title_suggest': 'Herland Illustrated',
#    'title_sort': 'Herland Illustrated',
#    'edition_count': 104,
#    'edition_key': ['OL29847262M',
#     'OL30319264M',
#     'OL30325696M',
#     'OL30357773M',
#     'OL34214743M',
#     'OL30334381M',
#     'OL29956311M',
#     'OL34211537M',
#     'OL34263415M',
#     'OL30008154M',
#     'OL30337819M',
#     'OL34130662M',
#     'OL36147924M',
#     'OL36151761M',
#     'OL36602364M',
#     'OL36590163M',
#     'OL36854011M',
#     'OL36872062M',
#     'OL36165308M',
#     'OL36060391M',
#     'OL35052869M',
#     'OL34289223M',
#     'OL37603261M',
#     'OL36170472M',
#     'OL34244325M',
#     'OL36461059M',
#     'OL36984634M',
#     'OL36855851M',
#     'OL34283889M',
#     'OL37646738M',
#     'OL36969369M',
#     'OL36994828M',
#     'OL36470239M',
#     'OL36599644M',
#     'OL37525379M',
#     'OL35239931M',
#     'OL35001276M',
#     'OL36073803M',
#     'OL36998686M',
#     'OL36590736M',
#     'OL35022080M',
#     'OL34303132M',
#     'OL37730828M',
#     'OL36474750M',
#     'OL36119205M',
#     'OL36455586M',
#     'OL36954128M',
#     'OL34329780M',
#     'OL34222038M',
#     'OL34324365M',
#     'OL35237900M',
#     'OL36587716M',
#     'OL37517519M',
#     'OL37525711M',
#     'OL36956539M',
#     'OL36900734M',
#     'OL36609165M',
#     'OL36990941M',
#     'OL36964115M',
#     'OL37497970M',
#     'OL34256306M',
#     'OL35165474M',
#     'OL36504273M',
#     'OL36599600M',
#     'OL35029854M',
#     'OL36598862M',
#     'OL37518756M',
#     'OL34343187M',
#     'OL34347869M',
#     'OL36072149M',
#     'OL36094880M',
#     'OL35018642M',
#     'OL34301333M',
#     'OL36045932M',
#     'OL36489357M',
#     'OL34121886M',
#     'OL37502832M',
#     'OL37501597M',
#     'OL34259687M',
#     'OL37566944M',
#     'OL34332105M',
#     'OL36089769M',
#     'OL34340358M',
#     'OL37529724M',
#     'OL34210315M',
#     'OL36505987M',
#     'OL36898698M',
#     'OL35024007M',
#     'OL36368116M',
#     'OL34327707M',
#     'OL37634283M',
#     'OL36990453M',
#     'OL36893750M',
#     'OL37527466M',
#     'OL36471150M',
#     'OL36987537M',
#     'OL36580128M',
#     'OL36992904M',
#     'OL34335003M',
#     'OL36996498M',
#     'OL36171279M',
#     'OL36606338M',
#     'OL34234886M',
#     'OL37699304M'],
#    'publish_date': ['2019', '2020', '2021', '2022'],
#    'publish_year': [2019, 2020, 2021, 2022],
#    'first_publish_year': 2019,
#    'number_of_pages_median': 195,
#    'isbn': ['9798462680632',
#     '9798771305707',
#     '9798453050543',
#     '9798763893038',
#     '9798617608054',
#     '9798731055932',
#     '9798455066870',
#     '9798454870218',
#     '9798472963459',
#     '9798787109016',
#     '9798525602014',
#     '9798482018828',
#     '9798748365475',
#     '9798753631138',
#     '9798488312005',
#     '9798778842823',
#     '9798648631137',
#     '9798530334962',
#     '9798713562328',
#     '9781694780546',
#     '9798480831542',
#     '9798481880310',
#     '9798740886282',
#     '9798650775812',
#     '9798461396978',
#     '9798531895547',
#     '9798455843518',
#     '9798403750462',
#     '9798509655012',
#     '9798450172231',
#     '9798537474449',
#     '9798721876332',
#     '9798488758100',
#     '9798733932095',
#     '9798480133356',
#     '9798514816330',
#     '9798500189356',
#     '9798452344087',
#     '9798462016325',
#     '9798523754340',
#     '9798493554599',
#     '9798651315918',
#     '9798469192725',
#     '9798788077505',
#     '9798643038863',
#     '9798584766702',
#     '9798484773459',
#     '9798521022595',
#     '9798472198677',
#     '9798776896040',
#     '9798521929511',
#     '9798463546234',
#     '9798501912663',
#     '9798526015738',
#     '9798511363455',
#     '9798478279257',
#     '9798468847237',
#     '9798494608222',
#     '9798542114736',
#     '9798485190958',
#     '9798533714686',
#     '9798473659924',
#     '9798531421432',
#     '9798634897400',
#     '9798766050605',
#     '9798756495065',
#     '9798741401613',
#     '9798751867713',
#     '9798501729346',
#     '9798462159824',
#     '9798490440406',
#     '1694780546',
#     '9798676156893',
#     '9798515041618',
#     '9798526199018',
#     '9798533315920',
#     '9798755217736',
#     '9798524229854',
#     '9798520389668',
#     '9798468098011',
#     '9798492234843',
#     '9798763011227',
#     '9798475495117',
#     '9798539464776',
#     '9798764034591',
#     '9798739894717',
#     '9798476886068',
#     '9798515480189',
#     '9798511724652',
#     '9798774597024',
#     '9798773940494',
#     '9798743667024',
#     '9798488898776',
#     '9798569261772',
#     '9798636819073',
#     '9798737288204',
#     '9798476757887',
#     '9798490960720',
#     '9798512033784',
#     '9798771313788',
#     '9798726548562',
#     '9798743119325',
#     '9798651624409',
#     '9798708519559',
#     '9798518355873'],
#    'last_modified_i': 1658517449,
#    'ebook_count_i': 0,
#    'ebook_access': 'no_ebook',
#    'has_fulltext': False,
#    'public_scan_b': False,
#    'readinglog_count': 6,
#    'want_to_read_count': 6,
#    'currently_reading_count': 0,
#    'already_read_count': 0,
#    'publisher': ['Independently Published'],
#    'language': ['eng'],
#    'author_key': ['OL408063A'],
#    'author_name': ['Charlotte Perkins Gilman'],
#    'author_alternative_name': ['Gilman, Charlotte Perkins',
#     'Charlotte perkins Gilman',
#     'Charlotte Perkins Perkins Gilman',
#     'Charlotte Perkins Gilman Gilman',
#     'Charlotte Perkins Stetson Gilman',
#     'CHARLOTTE PERKINS GILMAN',
#     'Charlotte Perkins 1860-1935 Gilman',
#     'Perkins Gilman',
#     'Charlotte P. Gilman',
#     'Charlotte Gilman',
#     'Gilman, Charlotte Perkins 1860-1935.',
#     'Charlotte Perkins, Gilman,',
#     'Charlotte, Perkins Gilman',
#     'Charlotte, Perkins Stetson Gilman',
#     'Charlotte (Perkins) Steton Gilman'],
#    'publisher_facet': ['Independently Published'],
#    '_version_': 1759765126443958272,
#    'author_facet': ['OL408063A Charlotte Perkins Gilman']},
#   {'key': '/works/OL24458295W',
#    'type': 'work',
#    'seed': ['/books/OL34811430M',
#     '/books/OL34427680M',
#     '/books/OL34427920M',
#     '/books/OL34413855M',
#     '/books/OL34831732M',
#     '/books/OL34431502M',
#     '/books/OL34828481M',
#     '/books/OL34832434M',
#     '/books/OL34446025M',
#     '/books/OL34445529M',
#     '/books/OL34454542M',
#     '/books/OL34832773M',
#     '/books/OL34455476M',
#     '/books/OL34446313M',
#     '/books/OL34446312M',
#     '/books/OL34435799M',
#     '/books/OL34830742M',
#     '/books/OL34850392M',
#     '/books/OL34445237M',
#     '/books/OL34852444M',
#     '/books/OL34471156M',
#     '/books/OL35855281M',
#     '/books/OL34860167M',
#     '/books/OL34873769M',
#     '/books/OL34876185M',
#     '/books/OL34874150M',
#     '/books/OL34892317M',
#     '/books/OL34888022M',
#     '/books/OL34881528M',
#     '/books/OL34885945M',
#     '/books/OL34892631M',
#     '/books/OL34888154M',
#     '/books/OL34891349M',
#     '/books/OL34894744M',
#     '/books/OL34892035M',
#     '/books/OL34892799M',
#     '/books/OL34890324M',
#     '/books/OL34898332M',
#     '/books/OL34895808M',
#     '/books/OL34894748M',
#     '/books/OL34892797M',
#     '/books/OL34891754M',
#     '/books/OL34900309M',
#     '/books/OL34907702M',
#     '/books/OL34908958M',
#     '/books/OL34903613M',
#     '/books/OL34908959M',
#     '/books/OL34910786M',
#     '/books/OL34911472M',
#     '/books/OL35282118M',
#     '/books/OL32397272M',
#     '/books/OL34912682M',
#     '/books/OL35281304M',
#     '/books/OL34753558M',
#     '/works/OL24458295W',
#     '/authors/OL7808031A'],
#    'title': 'Frenzied Fiction',
#    'title_suggest': 'Frenzied Fiction',
#    'title_sort': 'Frenzied Fiction',
#    'edition_count': 54,
#    'edition_key': ['OL34811430M',
#     'OL34427680M',
#     'OL34427920M',
#     'OL34413855M',
#     'OL34831732M',
#     'OL34431502M',
#     'OL34828481M',
#     'OL34832434M',
#     'OL34446025M',
#     'OL34445529M',
#     'OL34454542M',
#     'OL34832773M',
#     'OL34455476M',
#     'OL34446313M',
#     'OL34446312M',
#     'OL34435799M',
#     'OL34830742M',
#     'OL34850392M',
#     'OL34445237M',
#     'OL34852444M',
#     'OL34471156M',
#     'OL35855281M',
#     'OL34860167M',
#     'OL34873769M',
#     'OL34876185M',
#     'OL34874150M',
#     'OL34892317M',
#     'OL34888022M',
#     'OL34881528M',
#     'OL34885945M',
#     'OL34892631M',
#     'OL34888154M',
#     'OL34891349M',
#     'OL34894744M',
#     'OL34892035M',
#     'OL34892799M',
#     'OL34890324M',
#     'OL34898332M',
#     'OL34895808M',
#     'OL34894748M',
#     'OL34892797M',
#     'OL34891754M',
#     'OL34900309M',
#     'OL34907702M',
#     'OL34908958M',
#     'OL34903613M',
#     'OL34908959M',
#     'OL34910786M',
#     'OL34911472M',
#     'OL35282118M',
#     'OL32397272M',
#     'OL34912682M',
#     'OL35281304M',
#     'OL34753558M'],
#    'publish_date': ['2010',
#     '2018',
#     '2014',
#     '2016',
#     '2004',
#     '2008',
#     '2017',
#     'Oct 16, 2018',
#     '2009',
#     '2015',
#     'Oct 13, 2018',
#     '2021',
#     'Nov 13, 2018',
#     '2013',
#     '2012'],
#    'publish_year': [2010,
#     2014,
#     2016,
#     2004,
#     2008,
#     2017,
#     2021,
#     2009,
#     2015,
#     2018,
#     2013,
#     2012],
#    'first_publish_year': 2004,
#    'number_of_pages_median': 296,
#    'lcc': ['PR-9199.30000000.L367'],
#    'isbn': ['1530870704',
#     '9781497471191',
#     '141922090X',
#     '1374881082',
#     '9781347185308',
#     '1539630447',
#     '9780217818629',
#     '9781340596408',
#     '9781102751359',
#     '9781102119920',
#     '1143408292',
#     '114023921X',
#     '1341298256',
#     '9781530870707',
#     '9781535205900',
#     '1340596407',
#     '9781279269954',
#     '9781162663746',
#     '1535206772',
#     '198377619X',
#     '0554320630',
#     '1532960115',
#     '153295106X',
#     '9788132015277',
#     '1140239201',
#     '1497471192',
#     '0554227606',
#     '9781481269285',
#     '0343562804',
#     '1374881074',
#     '9781532825651',
#     '9781144690210',
#     '1169264212',
#     '1541219023',
#     '9781983776199',
#     '1161432396',
#     '9781530062423',
#     '1514368277',
#     '110211992X',
#     '1519635257',
#     '153006242X',
#     '9780353595187',
#     '177653669X',
#     '9781913724085',
#     '9781171569435',
#     '9781975637651',
#     '153282565X',
#     '9781536895841',
#     '9781419220906',
#     '9781406860337',
#     '9780343562809',
#     '1913724085',
#     '9781341298257',
#     '1728760836',
#     '0217818625',
#     '1347185305',
#     '9781374881075',
#     '9781376309935',
#     '9781532951060',
#     '0353595187',
#     '9781519335227',
#     '1406860336',
#     '1376309939',
#     '1536895849',
#     '9781153623315',
#     '1144690218',
#     '9781776536696',
#     '1481269283',
#     '9780554227603',
#     '1503371271',
#     '1171569432',
#     '9781489539151',
#     '9781978400078',
#     '116266374X',
#     '1153623315',
#     '1519335229',
#     '9781519635259',
#     '1975637658',
#     '9781541219021',
#     '1443417262',
#     '9781728760834',
#     '9781539630449',
#     '9781177559621',
#     '1102751359',
#     '1429780525',
#     '1489539158',
#     '1978400071',
#     '9781161432398',
#     '1279269952',
#     '9781503371279',
#     '9781443417266',
#     '9781374881082',
#     '8132015274',
#     '1545440506',
#     '9781140239215',
#     '9781140239208',
#     '1535205903',
#     '9781429780520',
#     '9781535206778',
#     '1177559625',
#     '9780554320632',
#     '9781143408298',
#     '9781545440506',
#     '9781407648897',
#     '9781532960116',
#     '9781169264212',
#     '1407648896',
#     '9781514368275'],
#    'last_modified_i': 1673679947,
#    'ebook_count_i': 0,
#    'ebook_access': 'no_ebook',
#    'has_fulltext': False,
#    'public_scan_b': False,
#    'cover_edition_key': 'OL32397272M',
#    'cover_i': 11060010,
#    'publisher': ['General Books LLC',
#     'Echo Library',
#     'Floating Press, The',
#     'Franklin Classics',
#     'Franklin Classics Trade Press',
#     'Hayes Barton Press',
#     'CreateSpace Independent Publishing Platform',
#     'Capital Communications, Incorporated',
#     'Creative Media Partners, LLC',
#     'HardPress',
#     'Independently Published',
#     'Seltzer Books',
#     'Independently published',
#     'HarperCollins Publishers',
#     'Kessinger Publishing, LLC',
#     'Simon & Schuster',
#     'Renard Press Ltd.',
#     'Cornell University Library'],
#    'language': ['eng'],
#    'author_key': ['OL7808031A'],
#    'author_name': ['Stephen Leacock'],
#    'publisher_facet': ['Capital Communications, Incorporated',
#     'Cornell University Library',
#     'CreateSpace Independent Publishing Platform',
#     'Creative Media Partners, LLC',
#     'Echo Library',
#     'Floating Press, The',
#     'Franklin Classics',
#     'Franklin Classics Trade Press',
#     'General Books LLC',
#     'HardPress',
#     'HarperCollins Publishers',
#     'Hayes Barton Press',
#     'Independently Published',
#     'Independently published',
#     'Kessinger Publishing, LLC',
#     'Renard Press Ltd.',
#     'Seltzer Books',
#     'Simon & Schuster'],
#    '_version_': 1759770248410562560,
#    'lcc_sort': 'PR-9199.30000000.L367',
#    'author_facet': ['OL7808031A Stephen Leacock']},
#   {'key': '/works/OL25601428W',
#    'type': 'work',
#    'seed': ['/books/OL34906051M',
#     '/books/OL34809071M',
#     '/books/OL34409376M',
#     '/books/OL34409377M',
#     '/books/OL34809226M',
#     '/books/OL34418618M',
#     '/books/OL34833507M',
#     '/books/OL34812378M',
#     '/books/OL34422890M',
#     '/books/OL34840160M',
#     '/books/OL34834060M',
#     '/books/OL34417633M',
#     '/books/OL34820160M',
#     '/books/OL34413486M',
#     '/books/OL34414266M',
#     '/books/OL34419604M',
#     '/books/OL34413348M',
#     '/books/OL34446898M',
#     '/books/OL34827538M',
#     '/books/OL34414187M',
#     '/books/OL34460067M',
#     '/books/OL34434686M',
#     '/books/OL34436076M',
#     '/books/OL34435690M',
#     '/books/OL34848007M',
#     '/books/OL34445509M',
#     '/books/OL34455192M',
#     '/books/OL34821321M',
#     '/books/OL34455505M',
#     '/books/OL34445712M',
#     '/books/OL34454442M',
#     '/books/OL34455458M',
#     '/books/OL34819175M',
#     '/books/OL34448864M',
#     '/books/OL34849715M',
#     '/books/OL34861233M',
#     '/books/OL34836313M',
#     '/books/OL34471353M',
#     '/books/OL34841261M',
#     '/books/OL34502146M',
#     '/books/OL34855465M',
#     '/books/OL34844595M',
#     '/books/OL34840696M',
#     '/books/OL34855272M',
#     '/books/OL34865749M',
#     '/books/OL34842435M',
#     '/books/OL34863554M',
#     '/books/OL34884509M',
#     '/books/OL34864918M',
#     '/books/OL34874329M',
#     '/books/OL34871107M',
#     '/books/OL34873242M',
#     '/books/OL34884573M',
#     '/books/OL34875939M',
#     '/books/OL34868028M',
#     '/books/OL34866775M',
#     '/books/OL34865836M',
#     '/books/OL34883388M',
#     '/books/OL34884533M',
#     '/books/OL34892536M',
#     '/books/OL34888815M',
#     '/books/OL34885328M',
#     '/books/OL34880696M',
#     '/books/OL34887410M',
#     '/books/OL34887408M',
#     '/books/OL34888787M',
#     '/books/OL34892289M',
#     '/books/OL34886301M',
#     '/books/OL34878525M',
#     '/books/OL34885697M',
#     '/books/OL34885198M',
#     '/books/OL34885528M',
#     '/books/OL34883900M',
#     '/books/OL34895414M',
#     '/books/OL34895410M',
#     '/books/OL34900083M',
#     '/books/OL34894702M',
#     '/books/OL34895499M',
#     '/books/OL34894498M',
#     '/books/OL34899543M',
#     '/books/OL34898907M',
#     '/books/OL34894497M',
#     '/books/OL34899373M',
#     '/books/OL34898198M',
#     '/books/OL34899237M',
#     '/books/OL34899444M',
#     '/books/OL34896189M',
#     '/books/OL34915234M',
#     '/books/OL34906877M',
#     '/books/OL34908476M',
#     '/books/OL34904524M',
#     '/books/OL34908435M',
#     '/books/OL34903471M',
#     '/books/OL34902882M',
#     '/subjects/juvenile_fiction',
#     '/subjects/history',
#     '/subjects/knights_and_knighthood',
#     '/authors/OL7470491A'],
#    'title': 'Men of Iron',
#    'title_suggest': 'Men of Iron',
#    'title_sort': 'Men of Iron',
#    'edition_count': 201,
#    'edition_key': ['OL34906051M',
#     'OL34809071M',
#     'OL34409376M',
#     'OL34409377M',
#     'OL34809226M',
#     'OL34418618M',
#     'OL34833507M',
#     'OL34812378M',
#     'OL34422890M',
#     'OL34840160M',
#     'OL34834060M',
#     'OL34417633M',
#     'OL34820160M',
#     'OL34413486M',
#     'OL34414266M',
#     'OL34419604M',
#     'OL34413348M',
#     'OL34446898M',
#     'OL34827538M',
#     'OL34414187M',
#     'OL34460067M',
#     'OL34434686M',
#     'OL34436076M',
#     'OL34435690M',
#     'OL34848007M',
#     'OL34445509M',
#     'OL34455192M',
#     'OL34821321M',
#     'OL34455505M',
#     'OL34445712M',
#     'OL34454442M',
#     'OL34455458M',
#     'OL34819175M',
#     'OL34448864M',
#     'OL34849715M',
#     'OL34861233M',
#     'OL34836313M',
#     'OL34471353M',
#     'OL34841261M',
#     'OL34502146M',
#     'OL34855465M',
#     'OL34844595M',
#     'OL34840696M',
#     'OL34855272M',
#     'OL34865749M',
#     'OL34842435M',
#     'OL34863554M',
#     'OL34884509M',
#     'OL34864918M',
#     'OL34874329M',
#     'OL34871107M',
#     'OL34873242M',
#     'OL34884573M',
#     'OL34875939M',
#     'OL34868028M',
#     'OL34866775M',
#     'OL34865836M',
#     'OL34883388M',
#     'OL34884533M',
#     'OL34892536M',
#     'OL34888815M',
#     'OL34885328M',
#     'OL34880696M',
#     'OL34887410M',
#     'OL34887408M',
#     'OL34888787M',
#     'OL34892289M',
#     'OL34886301M',
#     'OL34878525M',
#     'OL34885697M',
#     'OL34885198M',
#     'OL34885528M',
#     'OL34883900M',
#     'OL34895414M',
#     'OL34895410M',
#     'OL34900083M',
#     'OL34894702M',
#     'OL34895499M',
#     'OL34894498M',
#     'OL34899543M',
#     'OL34898907M',
#     'OL34894497M',
#     'OL34899373M',
#     'OL34898198M',
#     'OL34899237M',
#     'OL34899444M',
#     'OL34896189M',
#     'OL34915234M',
#     'OL34906877M',
#     'OL34908476M',
#     'OL34904524M',
#     'OL34908435M',
#     'OL34903471M',
#     'OL34902882M',
#     'OL34907746M',
#     'OL34902647M',
#     'OL34907730M',
#     'OL34905953M',
#     'OL34902733M',
#     'OL34911432M',
#     'OL34906200M',
#     'OL34906439M',
#     'OL34912015M',
#     'OL34904505M',
#     'OL34905241M',
#     'OL34910071M',
#     'OL34904211M',
#     'OL34907251M',
#     'OL34910765M',
#     'OL34904826M',
#     'OL34909939M',
#     'OL34902698M',
#     'OL34908438M',
#     'OL34900761M',
#     'OL34909025M',
#     'OL34900736M',
#     'OL34906196M',
#     'OL34909053M',
#     'OL34906018M',
#     'OL34902608M',
#     'OL34907186M',
#     'OL34919826M',
#     'OL34917005M',
#     'OL34941854M',
#     'OL34919720M',
#     'OL34924250M',
#     'OL34917597M',
#     'OL34929253M',
#     'OL34943265M',
#     'OL34919639M',
#     'OL34938519M',
#     'OL34914316M',
#     'OL34947674M',
#     'OL34918363M',
#     'OL34916709M',
#     'OL34916683M',
#     'OL34928713M',
#     'OL34915289M',
#     'OL34913899M',
#     'OL34915501M',
#     'OL34947864M',
#     'OL34915983M',
#     'OL34929336M',
#     'OL34943151M',
#     'OL34913872M',
#     'OL34933506M',
#     'OL34915008M',
#     'OL34920140M',
#     'OL34935629M',
#     'OL34943467M',
#     'OL34938463M',
#     'OL34933997M',
#     'OL34919742M',
#     'OL34914543M',
#     'OL34915552M',
#     'OL34952593M',
#     'OL34918348M',
#     'OL34914809M',
#     'OL34914340M',
#     'OL34921727M',
#     'OL34919585M',
#     'OL34943526M',
#     'OL34928712M',
#     'OL34942960M',
#     'OL34916713M',
#     'OL34917601M',
#     'OL34916721M',
#     'OL34915709M',
#     'OL34919740M',
#     'OL34928719M',
#     'OL34916969M',
#     'OL34917862M',
#     'OL34952525M',
#     'OL34914342M',
#     'OL34915025M',
#     'OL34933502M',
#     'OL34924227M',
#     'OL34938831M',
#     'OL34919483M',
#     'OL34934461M',
#     'OL34925282M',
#     'OL34953641M',
#     'OL34940637M',
#     'OL34953707M',
#     'OL34945211M',
#     'OL34931372M',
#     'OL34930620M',
#     'OL34925276M',
#     'OL34964228M',
#     'OL34966656M',
#     'OL34981385M',
#     'OL34946218M',
#     'OL34966650M',
#     'OL34937018M',
#     'OL34966621M',
#     'OL34963440M',
#     'OL34964166M',
#     'OL34946331M',
#     'OL34923041M',
#     'OL34343703M',
#     'OL34992478M'],
#    'publish_date': ['2008',
#     '1891',
#     '2006',
#     '2009',
#     '2013',
#     '2002',
#     '2015',
#     '2012',
#     '2016',
#     '2018',
#     '2004',
#     '2019',
#     '2020',
#     '2021',
#     '2010',
#     '2017',
#     '2014',
#     '2011'],
#    'publish_year': [2008,
#     2006,
#     2013,
#     2009,
#     2002,
#     2018,
#     2019,
#     2004,
#     2020,
#     2021,
#     2010,
#     2014,
#     2017,
#     2011,
#     1891,
#     2015,
#     2012,
#     2016],
#    'first_publish_year': 1891,
#    'number_of_pages_median': 272,
#    'isbn': ['9781979332316',
#     '9781720718024',
#     '1535108177',
#     '9781976495755',
#     '172089552X',
#     '9781722688752',
#     '9781366589385',
#     '9781449594787',
#     '9781605121581',
#     '9781376442106',
#     '1372290095',
#     '9781724808684',
#     '1798272008',
#     '197649575X',
#     '9781495954771',
#     '1536820857',
#     '1546523723',
#     '117173770X',
#     '1974320979',
#     '9781726437226',
#     '1356084184',
#     '1986381986',
#     '9781986790499',
#     '114279721X',
#     '1985081148',
#     '1978123639',
#     '9781725700765',
#     '048612245X',
#     '9798583788699',
#     '9781725045644',
#     '9781515363866',
#     '1981411615',
#     '1341381315',
#     '172937008X',
#     '1726394069',
#     '1366554124',
#     '1985810964',
#     '1719467390',
#     '9781649651839',
#     '1798471876',
#     '9780613860949',
#     '9781976002304',
#     '9781548723125',
#     '9781974161379',
#     '9781482037487',
#     '1515363864',
#     '9781341381317',
#     '9781986226226',
#     '9781721250905',
#     '1725045648',
#     '1502596040',
#     '1599152940',
#     '9781546523727',
#     '9781502596048',
#     '9781517396220',
#     '9781539449362',
#     '1718813716',
#     '9781719467391',
#     '1605121584',
#     '9781729358771',
#     '1544126190',
#     '9781522895053',
#     '9781725150928',
#     '9781981208173',
#     '9781727005141',
#     '9781475305043',
#     '1548884146',
#     '9781722968267',
#     '9781987663310',
#     '1986473252',
#     '1542319595'],
#    'last_modified_i': 1670376246,
#    'ebook_count_i': 1,
#    'ebook_access': 'borrowable',
#    'has_fulltext': True,
#    'public_scan_b': False,
#    'ia': ['menofiron0000pyle_o9u4'],
#    'ia_collection': ['inlibrary', 'internetarchivebooks', 'printdisabled'],
#    'ia_collection_s': 'inlibrary;internetarchivebooks;printdisabled',
#    'lending_edition_s': 'OL34414266M',
#    'lending_identifier_s': 'menofiron0000pyle_o9u4',
#    'printdisabled_s': 'OL34414266M',
#    'readinglog_count': 15,
#    'want_to_read_count': 15,
#    'currently_reading_count': 0,
#    'already_read_count': 0,
#    'cover_edition_key': 'OL34414266M',
#    'cover_i': 12674639,
#    'publisher': ['Arc Manor',
#     'Floating Press, The',
#     'CreateSpace Independent Publishing Platform',
#     '1st World Publishing, Incorporated',
#     'Charles River Editors',
#     'Blurb, Incorporated',
#     'Simon & Schuster',
#     'Independently Published',
#     'Literary Licensing, LLC',
#     'Digireads.com Publishing',
#     'Creative Media Partners, LLC',
#     'Echo Library',
#     'HardPress',
#     'Dover Publications, Incorporated',
#     'Turtleback',
#     'New West Press',
#     'Crushed Lime Media, LLC',
#     'Read Books',
#     'IndyPublish.com',
#     'Seltzer Books',
#     'Akasha Publishing, LLC',
#     "Yesterday's Classics",
#     'ReadaClassic.com',
#     'General Books LLC',
#     'Tredition GmbH',
#     'Doherty Associates, LLC, Tom',
#     'Kessinger Publishing, LLC'],
#    'language': ['eng'],
#    'author_key': ['OL7470491A'],
#    'author_name': ['Howard Pyle'],
#    'subject': ['Juvenile fiction', 'History', 'Knights and knighthood'],
#    'ia_box_id': ['IA40400907'],
#    'publisher_facet': ['1st World Publishing, Incorporated',
#     'Akasha Publishing, LLC',
#     'Arc Manor',
#     'Blurb, Incorporated',
#     'Charles River Editors',
#     'CreateSpace Independent Publishing Platform',
#     'Creative Media Partners, LLC',
#     'Crushed Lime Media, LLC',
#     'Digireads.com Publishing',
#     'Doherty Associates, LLC, Tom',
#     'Dover Publications, Incorporated',
#     'Echo Library',
#     'Floating Press, The',
#     'General Books LLC',
#     'HardPress',
#     'Independently Published',
#     'IndyPublish.com',
#     'Kessinger Publishing, LLC',
#     'Literary Licensing, LLC',
#     'New West Press',
#     'Read Books',
#     'ReadaClassic.com',
#     'Seltzer Books',
#     'Simon & Schuster',
#     'Tredition GmbH',
#     'Turtleback',
#     "Yesterday's Classics"],
#    'subject_facet': ['History', 'Juvenile fiction', 'Knights and knighthood'],
#    '_version_': 1759772127655886848,
#     '/books/OL36849698M',
#     '/books/OL38535828M',
#     '/books/OL36455322M',
#     '/books/OL38137470M',
#     '/books/OL37498206M',
#     '/books/OL34135844M',
#     '/books/OL38486713M',
#     '/books/OL35218868M',
#     '/books/OL38200970M',
#     '/books/OL38176543M',
#     '/books/OL34999993M',
#     '/books/OL36871182M',
#     '/books/OL37596134M',
#     '/books/OL38501818M',
#     '/books/OL34353678M',
#     '/books/OL36505120M',
#     '/books/OL38140766M',
#     '/books/OL38138151M',
#     '/books/OL38463028M',
#     '/books/OL34210334M',
#     '/books/OL35013150M',
#     '/books/OL38144741M',
#     '/books/OL37508765M',
#     '/books/OL34359180M',
#     '/books/OL37635114M',
#     '/books/OL38467559M',
#     '/books/OL35070899M',
#     '/books/OL36512851M',
#     '/books/OL38512581M',
#     '/books/OL38546345M',
#     '/books/OL38496372M',
#     '/books/OL38510953M',
#     '/books/OL38202776M',
#     '/books/OL34343422M',
#     '/books/OL38477837M',
#     '/books/OL38190704M',
#     '/books/OL38538482M',
#     '/books/OL38546631M',
#     '/books/OL38548346M',
#     '/books/OL38438564M',
#     '/books/OL38167606M',
#     '/books/OL38113910M',
#     '/books/OL38437909M',
#     '/books/OL38168602M',
#     '/books/OL38165744M',
#     '/works/OL21996172W',
#     '/authors/OL2163969A'],
#    'title': 'Beasts and Super-Beasts Illustrated',
#    'title_suggest': 'Beasts and Super-Beasts Illustrated',
#    'title_sort': 'Beasts and Super-Beasts Illustrated',
#    'edition_count': 147,
#    'edition_key': ['OL35117337M',
#     'OL34234484M',
#     'OL30002031M',
#     'OL38513882M',
#     'OL36526463M',
#     'OL30321562M',
#     'OL30335780M',
#     'OL30362983M',
#     'OL30337368M',
#     'OL30325125M',
#     'OL36920953M',
#     'OL36090299M',
#     'OL34242990M',
#     'OL30331271M',
#     'OL30053526M',
#     'OL38434694M',
#     'OL37522380M',
#     'OL37660865M',
#     'OL36923153M',
#     'OL36850392M',
#     'OL38478279M',
#     'OL38452052M',
#     'OL38529829M',
#     'OL36875127M',
#     'OL36982582M',
#     'OL34248533M',
#     'OL38443888M',
#     'OL35024357M',
#     'OL37653896M',
#     'OL37560862M',
#     'OL38513424M',
#     'OL36494304M',
#     'OL36610399M',
#     'OL36169084M',
#     'OL36577338M',
#     'OL36980667M',
#     'OL36165285M',
#     'OL38442694M',
#     'OL35114004M',
#     'OL38444876M',
#     'OL36503332M',
#     'OL38460366M',
#     'OL34309587M',
#     'OL38553381M',
#     'OL36059396M',
#     'OL36610635M',
#     'OL38127113M',
#     'OL36844833M',
#     'OL37601898M',
#     'OL35072065M',
#     'OL36037817M',
#     'OL34309715M',
#     'OL35069494M',
#     'OL36049772M',
#     'OL36059529M',
#     'OL38495795M',
#     'OL34298087M',
#     'OL38514532M',
#     'OL38193914M',
#     'OL37526946M',
#     'OL36584872M',
#     'OL36070391M',
#     'OL36490580M',
#     'OL36123520M',
#     'OL36981104M',
#     'OL38503202M',
#     'OL37697386M',
#     'OL38468173M',
#     'OL34280240M',
#     'OL36159479M',
#     'OL37555984M',
#     'OL38444030M',
#     'OL36987157M',
#     'OL38512619M',
#     'OL38469129M',
#     'OL38416821M',
#     'OL38444552M',
#     'OL36492438M',
#     'OL37607003M',
#     'OL34357168M',
#     'OL38104204M',
#     'OL36924247M',
#     'OL36498319M',
#     'OL36068367M',
#     'OL36526169M',
#     'OL36969451M',
#     'OL38131972M',
#     'OL38164736M',
#     'OL36028255M',
#     'OL38463210M',
#     'OL38433447M',
#     'OL34312418M',
#     'OL36488447M',
#     'OL36907120M',
#     'OL37660433M',
#     'OL36037467M',
#     'OL36955003M',
#     'OL38435265M',
#     'OL38171831M',
#     'OL34326406M',
#     'OL35243122M',
#     'OL38443382M',
#     'OL36849698M',
#     'OL38535828M',
#     'OL36455322M',
#     'OL38137470M',
#     'OL37498206M',
#     'OL34135844M',
#     'OL38486713M',
#     'OL35218868M',
#     'OL38200970M',
#     'OL38176543M',
#     'OL34999993M',
#     'OL36871182M',
#     'OL37596134M',
#     'OL38501818M',
#     'OL34353678M',
#     'OL36505120M',
#     'OL38140766M',
#     'OL38138151M',
#     'OL38463028M',
#     'OL34210334M',
#     'OL35013150M',
#     'OL38144741M',
#     'OL37508765M',
#     'OL34359180M',
#     'OL37635114M',
#     'OL38467559M',
#     'OL35070899M',
#     'OL36512851M',
#     'OL38512581M',
#     'OL38546345M',
#     'OL38496372M',
#     'OL38510953M',
#     'OL38202776M',
#     'OL34343422M',
#     'OL38477837M',
#     'OL38190704M',
#     'OL38538482M',
#     'OL38546631M',
#     'OL38548346M',
#     'OL38438564M',
#     'OL38167606M',
#     'OL38113910M',
#     'OL38437909M',
#     'OL38168602M',
#     'OL38165744M'],
#    'publish_date': ['2022', '2021', '2020'],
#    'publish_year': [2022, 2021, 2020],
#    'first_publish_year': 2020,
#    'number_of_pages_median': 236,
#    'isbn': ['9798702192352',
#     '9798678958242',
#     '9798526523660',
#     '9798452343189',
#     '9798478508074',
#     '9798777031594',
#     '9798525499942',
#     '9798521698769',
#     '9798523329203',
#     '9798719428383',
#     '9798487184054',
#     '9798458784085',
#     '9798483844464',
#     '9798543858950',
#     '9798508556853',
#     '9798772028230',
#     '9798472012263',
#     '9798499845646',
#     '9798526550987',
#     '9798754138728',
#     '9798461929572',
#     '1660334284',
#     '9798541027617',
#     '9798424262968',
#     '9798748808200',
#     '9798411444964',
#     '9798541659726',
#     '9798731055420',
#     '9798736696604',
#     '9798755386043',
#     '9798633352788',
#     '9798647044150',
#     '9798785597143',
#     '9798520361121',
#     '9798430906870',
#     '9798499197943',
#     '9798528564838',
#     '9798528373898',
#     '9798508287139',
#     '9798745957048',
#     '9798526991797',
#     '9798511100043',
#     '9798527900538',
#     '9798770878172',
#     '9798758021835',
#     '9798525256729',
#     '9798725038606',
#     '9798549251939',
#     '9798501577367',
#     '9798533208406',
#     '9798544578239',
#     '9798722952004',
#     '9798531020277',
#     '9798539299507',
#     '9798784824585',
#     '9798544049791',
#     '9798832637433',
#     '9798596803921',
#     '9798465693981',
#     '9798465790864',
#     '9798437478141',
#     '9798462658839',
#     '9798537499046',
#     '9798708345738',
#     '9798712357017',
#     '9798543408025',
#     '9798777122094',
#     '9798688511031',
#     '9798503881318',
#     '9798492945305',
#     '9798464388123',
#     '9798540744829',
#     '9798732843019',
#     '9798760891211',
#     '9798734660577',
#     '9798473488531',
#     '9798515752545',
#     '9798721516979',
#     '9798421554691',
#     '9798479283710',
#     '9798749754674',
#     '9798523303791',
#     '9798560473761',
#     '9798479934544',
#     '9798463700414',
#     '9798775177317',
#     '9798750490042',
#     '9798527026344',
#     '9798570786202',
#     '9798518543034',
#     '9798522430276',
#     '9798498875781',
#     '9798722130112',
#     '9798777339140',
#     '9798530134951',
#     '9798511003115',
#     '9798487025944',
#     '9798755519533',
#     '9798516165450',
#     '9798656525589',
#     '9798478344740',
#     '9798473318104',
#     '9798413434185',
#     '9798637775019',
#     '9798484470372',
#     '9798470501264',
#     '9798530496738',
#     '9781660334285',
#     '9798547541476',
#     '9798467064437',
#     '9798733076546',
#     '9798464934085',
#     '9798789235201',
#     '9798652129149',
#     '9798455387951',
#     '9798462774911',
#     '9798517580429',
#     '9798525513792',
#     '9798513371700',
#     '9798728677482',
#     '9798670746854',
#     '9798515077297',
#     '9798425971388',
#     '9798731521505',
#     '9798458233385',
#     '9798789051078',
#     '9798486533860',
#     '9798524987303',
#     '9798550503294',
#     '9798523594939',
#     '9798638237233',
#     '9798726377940',
#     '9798487579324',
#     '9798461098049',
#     '9798532169098',
#     '9798477568895',
#     '9798667296386',
#     '9798642869130',
#     '9798524551702',
#     '9798595779692',
#     '9798453273614',
#     '9798463390394',
#     '9798827088769',
#     '9798787370553',
#     '9798523493201',
#     '9798545619290',
#     '9798795195735',
#     '9798416361518'],
#    'last_modified_i': 1655682874,
#    'ebook_count_i': 0,
#    'ebook_access': 'no_ebook',
#    'has_fulltext': False,
#    'public_scan_b': False,
#    'readinglog_count': 4,
#    'want_to_read_count': 4,
#    'currently_reading_count': 0,
#    'already_read_count': 0,
#    'publisher': ['Independently Published'],
#    'language': ['eng'],
#    'author_key': ['OL2163969A'],
#    'author_name': ['Hugh Munro'],
#    'publisher_facet': ['Independently Published'],
#    '_version_': 1759765312070221825,
#    'author_facet': ['OL2163969A Hugh Munro']},
#   {'key': '/works/OL21901180W',
#    'type': 'work',
#    'seed': ['/books/OL29870597M',
#     '/books/OL29983005M',
#     '/books/OL30321990M',
#     '/books/OL36161269M',
#     '/books/OL30325459M',
#     '/books/OL30320861M',
#     '/books/OL35116372M',
#     '/books/OL30334109M',
#     '/books/OL30325715M',
#     '/books/OL36089383M',
#     '/books/OL29931895M',
#     '/books/OL36609265M',
#     '/books/OL30325642M',
#     '/books/OL29936989M',
#     '/books/OL36901936M',
#     '/books/OL36513083M',
#     '/books/OL38460712M',
#     '/books/OL38444425M',
#     '/books/OL36494378M',
#     '/books/OL38435725M',
#     '/books/OL36490180M',
#     '/books/OL35105226M',
#     '/books/OL37005149M',
#     'OL8481921M',
#     'OL8898347M',
#     'OL9677050M',
#     'OL9647209M',
#     'OL9633189M',
#     'OL11878160M',
#     'OL9556557M',
#     'OL9609652M',
#     'OL9743355M',
#     'OL36715729M',
#     'OL36218165M',
#     'OL40751305M',
#     'OL40774740M',
#     'OL40954898M',
#     'OL41047594M',
#     'OL41143054M',
#     'OL41143291M',
#     'OL40666030M',
#     'OL40774954M',
#     'OL41106088M',
#     'OL40778023M',
#     'OL40977010M',
#     'OL41059529M',
#     'OL41107155M',
#     'OL41134305M',
#     'OL41135778M',
#     'OL41153400M',
#     'OL41199351M',
#     'OL41263454M',
#     'OL41307572M',
#     'OL41318214M',
#     'OL41389891M',
#     'OL41402167M',
#     'OL41486788M',
#     'OL41526966M',
#     'OL41603482M',
#     'OL41668245M',
#     'OL41910083M',
#     'OL40564320M',
#     'OL40615599M',
#     'OL40888045M',
#     'OL40950201M',
#     'OL41089393M',
#     'OL41135753M',
#     'OL41150544M',
#     'OL41180996M',
#     'OL41212703M',
#     'OL41231539M',
#     'OL41232955M',
#     'OL41315002M',
#     'OL41368192M',
#     'OL41404490M',
#     'OL41422539M',
#     'OL41435625M',
#     'OL41462238M',
#     'OL41468181M',
#     'OL41491785M',
#     'OL41509048M',
#     'OL41528905M',
#     'OL41529353M',
#     'OL41534876M',
#     'OL41540540M',
#     'OL41567024M',
#     'OL41587084M',
#     'OL41613003M',
#     'OL41621884M',
#     'OL41796238M',
#     'OL39355151M',
#     'OL39541185M',
#     'OL28641072M',
#     'OL42274473M',
#     'OL42000530M',
#     'OL42051231M',
#     'OL42340140M',
#     'OL42367918M',
#     'OL42600930M',
#     'OL41891045M',
#     'OL41965430M',
#     'OL42078762M',
#     'OL42151351M',
#     'OL42207538M',
#     'OL42228634M',
#     'OL38240414M',
#     'OL38056603M',
#     'OL30251848M',
#     'OL42613824M',
#     'OL42487325M',
#     'OL38537344M',
#     'OL38442808M',
#     'OL38419623M',
#     'OL38127142M',
#     'OL36994709M',
#     'OL38108587M',
#     'OL36607348M',
#     'OL36177344M',
#     'OL36907342M',
#     'OL36891791M',
#     'OL36476340M',
#     'OL36472418M',
#     'OL37044689M',
#     'OL37509702M',
#     'OL36134814M',
#     'OL37606122M',
#     'OL34289916M',
#     'OL34298816M',
#     'OL36592478M',
#     'OL34237051M',
#     'OL34210071M',
#     'OL36089673M',
#     'OL42659119M',
#     'OL42632971M',
#     'OL38924004M',
#     'OL39684407M',
#     'OL38465558M',
#     'OL38534173M',
#     'OL38098676M',
#     'OL38106368M'],
#    'publish_date': ['2017',
#     'July 12, 2007',
#     '2021',
#     '2022',
#     'August 31, 2004',
#     'Jan 10, 2019',
#     'March 1987',
#     'June 30, 2004',
#     'Jul 14, 2020',
#     '2018',
#     'November 3, 2006',
#     'April 30, 2006',
#     '1978',
#     'March 1, 1987',
#     '1919',
#     'October 7, 2006',
#     'January 30, 1996',
#     'December 1, 2005',
#     '2020',
#     '2015',
#     '1927',
#     'Jul 28, 2021',
#     '2019',
#     '1980',
#     '2013'],
#    'publish_year': [2017,
#     1919,
#     2021,
#     2006,
#     2022,
#     2020,
#     2005,
#     2007,
#     2015,
#     1927,
#     2004,
#     2018,
#     1987,
#     2019,
#     1978,
#     1996,
#     1980,
#     2013],
#    'first_publish_year': 1919,
#    'number_of_pages_median': 248,
#    'lccn': ['79054145', '19015735'],
#    'publish_place': ['New York', 'London', 'Bath'],
#    'oclc': ['6549220', '14587045', '36451171'],
#    'contributor': ['Flo Gibson (Narrator)'],
#    'lcc': ['PR-6011.00000000.L5 Mi 1980',
#     'PZ-0003.00000000.F634 Mi',
#     'PR-6011.00000000.L5',
#     'PR-6011.00000000.L5 Mi',
#     'PZ-0003.00000000.F634 Mi 1980'],
#    'ddc': ['823.912'],
#    'isbn': ['9798529910887',
#     '9781085952972',
#     '1797881329',
#     '1090174519',
#     '9798544058441',
#     '1426441266',
#     '1658261631',
#     '9781085952811',
#     '9798540603317',
#     '9781697851908',
#     '9781072606277',
#     '1697851908',
#     '1090813856',
#     '9781694790521',
#     '107665116X',
#     '1796590010',
#     '9781693159534',
#     '9798775676971',
#     '9781435316799',
#     '9798818853178',
#     '9781080708666',
#     '9781790897742',
#     '1076651186',
#     '9780850467864',
#     '1070539996',
#     '9781731531544',
#     '1598187422',
#     '9781480453449',
#     '1080681078',
#     '1098920317',
#     '1699169411',
#     '9781098920319',
#     '0809566281',
#     '9781078298698',
#     '9781690113973',
#     '1696174309',
#     '1731379854',
#     '9781791881696',
#     '9780706607260',
#     '1070649678',
#     '9781080681075',
#     '169679286X',
#     '1690113944',
#     '9781796590012',
#     '9798758949962',
#     '9798753074881',
#     '9798589530957',
#     '9781690116387',
#     '9781699169414',
#     '9798498577302',
#     '1406903973',
#     '9781090513007',
#     '9798627472911',
#     '1693160005',
#     '1098941187',
#     '9781675946244',
#     '1687140766',
#     '9781699093108',
#     '1792818513',
#     '1675946248',
#     '1435316797',
#     '1791881696',
#     '1099602874',
#     '0008283044',
#     '9781090813855',
#     '9781689970266',
#     '1479440221',
#     '9798538586875',
#     '9798551205616',
#     '9781701794238',
#     '9798711792505',
#     '9781098941185',
#     '1480453447',
#     '9781421974927',
#     '1421974908',
#     '9781598187427',
#     '9780933852662',
#     '9781419172755',
#     '1693159538',
#     '1794590846',
#     '1080708669',
#     '9798403086011',
#     '1796491012',
#     '9798739654960',
#     '9798696851037',
#     '9798419094369',
#     '9781790599271',
#     '1699093105',
#     '1419172751',
#     '9781521085745',
#     '9781076651167',
#     '1448213207',
#     '0850467861',
#     '9781675999813',
#     '9781797881324',
#     '9798636831563',
#     '9781696885591',
#     '9781712910054',
#     '9781658296045',
#     '9781658261630',
#     '0933852665',
#     '1097293734',
#     '1078298696',
#     '1686965036',
#     '1730995934',
#     '9781076651181',
#     '1034643320',
#     '9798535307619',
#     '9781090174512',
#     '9781687140760',
#     '1421974924',
#     '9798700940672',
#     '9798705222971',
#     '9798798418602',
#     '9781796491012',
#     '9781099602870',
#     '9798777779175',
#     '9798447084035',
#     '1792038054',
#     '9781097197392',
#     '9798627106441',
#     '0008283052',
#     '9780809566280',
#     '1795329262',
#     '1435316959',
#     '9781791997434',
#     '1790897742',
#     '1731531540',
#     '9781731379856',
#     '1694790525',
#     '9781479440221',
#     '9780008283056',
#     '9780486239101',
#     '1690113979',
#     '9798683855031',
#     '9781426440670',
#     '9781034643326',
#     '1675999813',
#     '9781426441264',
#     '1090659474',
#     '9798594774766',
#     '9798413803820',
#     '9781556854491',
#     '9781421974903',
#     '9781795121033',
#     '1521085749',
#     '9781730995934',
#     '9781070539997',
#     '9798620972197',
#     '9798666840931',
#     '9781690113942',
#     '9781696174305',
#     '9781072634249',
#     '9798694717885',
#     '9781696792868',
#     '9781097293735',
#     '1690116382',
#     '0706607260',
#     '0486239101',
#     '1097197395',
#     '1696885590',
#     '9798420919835',
#     '1712910051',
#     '1795121033',
#     '9780008283049',
#     '9781693160004',
#     '1085952975',
#     '1072606275',
#     '168997026X',
#     '1701794233',
#     '9798547885549',
#     '169596392X',
#     '0947898522',
#     '9781695963924',
#     '1085952819',
#     '9780947898526',
#     '179059927X',
#     '9798522145880',
#     '9798819521090',
#     '9781090659477',
#     '9781406903973',
#     '1072634244',
#     '1556854498',
#     '1791997430',
#     '9781686965036',
#     '1090513003',
#     '1658296044',
#     '9798536737538',
#     '9798693650121',
#     '1426440677',
#     '9798582281436',
#     '9781795329262',
#     '9781794590847',
#     '9781792038051',
#     '9781435316959',
#     '9781792818516',
#     '9798534919516',
#     '1644393964',
#     '9781070649672',
#     '9798636831808',
#     '9781644393963',
#     '9781448213207',
#     '9798751660987',
#     '9798472584739'],
#    'last_modified_i': 1679103211,
#    'ebook_count_i': 3,
#    'ebook_access': 'public',
#    'has_fulltext': True,
#    'public_scan_b': True,
#    'ia': ['middletemplemurd00flet_0', 'middletemplemur00fletgoog'],
#    'ia_collection': ['americana', 'prscr', 'unclibraries'],
#    'ia_collection_s': 'americana;prscr;unclibraries',
#    'lending_edition_s': 'OL33191522M',
#    'lending_identifier_s': 'middletemplemurd00flet_0',
#    'ratings_average': 3.0,
#    'ratings_sortable': 2.1948824,
#    'ratings_count': 1,
#    'ratings_count_1': 0,
#    'ratings_count_2': 0,
#    'ratings_count_3': 1,
#    'ratings_count_4': 0,
#    'ratings_count_5': 0,
#    'readinglog_count': 9,
#    'want_to_read_count': 8,
#    'currently_reading_count': 0,
#    'already_read_count': 1,
#    'cover_edition_key': 'OL6619437M',
#    'cover_i': 5842420,
#    'first_sentence': ["As a rule, Spargo left the Watchman office at two o'clock."],
#    'publisher': ['IndyPublish.com',
#     'Aegypan',
#     'Dover Publications',
#     'Ward, Lock & Co',
#     'Greenhill Books',
#     'A.A. Knopf',
#     'Nautical & Aviation Publishing Company of Ame',
#     'Wildside Press, LLC',
#     'MysteriousPress.com',
#     'Bloomsbury Publishing Plc',
#     'HarperCollins Publishers Limited',
#     'Remploy',
#     'Wildside Press',
#     'BiblioBazaar',
#     'IndoEuropeanPublishing.com',
#     'Hard Press',
#     'Audio Book Contractors, Inc.',
#     'Indoeuropeanpublishing.com',
#     'Kessinger Publishing',
#     'Lythway Press',
#     'Collins Crime Club',
#     'Grosset & Dunlap',
#     'IndyPublish',
#     'Standard Ebooks',
#     'Independently Published',
#     'Blurb'],
#    'language': ['eng', 'fre'],
#    'author_key': ['OL215843A'],
#    'author_name': ['Joseph Smith Fletcher'],
#    'author_alternative_name': ['Joseph S. Fletcher',
#     'J. fletcher',
#     'J. S. J. S. Fletcher',
#     'Joseph SmithFletcher',
#     'Joseph Smith FLETCHER',
#     'J.S. Fletcher',
#     'Fletcher, Joseph Smith (1863-1935)',
#     'J. s. Fletcher',
#     'J. S. FLETCHER',
#     'J. S Fletcher',
#     'J. J. S.Fletcher',
#     'S. J. Fletcher',
#     'J S. 1863-1935 Fletcher',
#     'J S Fletcher',
#     'Fletcher J. S. (Joseph Smith)',
#     'J S. Fletcher',
#     'Smith Joseph Fletcher',
#     'Joseph Smith Joseph Smith Fletcher',
#     'J. S. (Joseph Smith) Fletcher',
#     'J. S. Fletcher',
#     'J. S. 1863-1935 Fletcher',
#     'J. S. Fletcher Fletcher',
#     'Joseph S Fletcher',
#     'Joseph Smith Fletcher',
#     'J., S. Fletcher',
#     'J.S Fletcher',
#     'Joseph Smith Fletcher Smith Fletcher'],
#    'subject': ['Fiction in English',
#     'London (england), fiction',
#     'Journalists, fiction',
#     'Crime, fiction',
#     'Fiction, mystery & detective, general'],
#    'time': ['1910s'],
#    'id_goodreads': ['4656514', '6308016', '6440728', '7242038'],
#    'id_librarything': ['614132'],
#    'id_standard_ebooks': ['j-s-fletcher/the-middle-temple-murder'],
#    'publisher_facet': ['A.A. Knopf',
#     'Aegypan',
#     'Audio Book Contractors, Inc.',
#     'BiblioBazaar',
#     'Bloomsbury Publishing Plc',
#     'Blurb',
#     'Collins Crime Club',
#     'Dover Publications',
#     'Greenhill Books',
#     'Grosset & Dunlap',
#     'Hard Press',
#     'HarperCollins Publishers Limited',
#     'Independently Published',
#     'IndoEuropeanPublishing.com',
#     'Indoeuropeanpublishing.com',
#     'IndyPublish',
#     'IndyPublish.com',
#     'Kessinger Publishing',
#     'Lythway Press',
#     'MysteriousPress.com',
#     'Nautical & Aviation Publishing Company of Ame',
#     'Remploy',
#     'Standard Ebooks',
#     'Ward, Lock & Co',
#     'Wildside Press',
#     'Wildside Press, LLC'],
#    'time_facet': ['1910s'],
#    'subject_facet': ['Crime, fiction',
#     'Fiction in English',
#     'Fiction, mystery & detective, general',
#     'Journalists, fiction',
#     'London (england), fiction'],
#    '_version_': 1760667333367431168,
#    'lcc_sort': 'PR-6011.00000000.L5 Mi 1980',
#    'author_facet': ['OL215843A Joseph Smith Fletcher'],
#    'subject_key': ['crime_fiction',
#     'fiction_in_english',
#     'fiction_mystery__detective_general',
#     'journalists_fiction',
#     'london_(england)_fiction'],
#    'ddc_sort': '823.912',
#    'time_key': ['1910s']}],
#  'num_found': 1450694,
#  'q': 'fiction',
#  'offset': None}

# %%
data['docs'][0]['subject_key']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/w7/7cfd14hn02g0d126w5q47rqw0000gn/T/ipykernel_7545/3012213440.py in <module>
# ----> 1 data['docs'][0]['subject_key']
#
# KeyError: 'subject_key'

# %%
# Main keys
data.keys()
# Out:
# dict_keys(['numFound', 'start', 'numFoundExact', 'docs', 'num_found', 'q', 'offset'])

# %% [markdown]
# ['numFound', 'start', 'numFoundExact', 'docs', 'num_found', 'q', 'offset']

# %%
data['numFound']
# Out:
# 1450694

# %%
data['start']
# Out:
# 0

# %%
data['numFoundExact']
# Out:
# True

# %%
data['num_found']
# Out:
# 1450694

# %%
data['q'] # main genre
# Out:
# 'fiction'

# %%
data['offset']

# %%
# Data docs
data['docs'][0].keys()
# Out:
# dict_keys(['key', 'type', 'seed', 'title', 'title_suggest', 'title_sort', 'edition_count', 'edition_key', 'publish_date', 'publish_year', 'first_publish_year', 'number_of_pages_median', 'isbn', 'last_modified_i', 'ebook_count_i', 'ebook_access', 'has_fulltext', 'public_scan_b', 'readinglog_count', 'want_to_read_count', 'currently_reading_count', 'already_read_count', 'publisher', 'language', 'author_key', 'author_name', 'author_alternative_name', 'publisher_facet', '_version_', 'author_facet'])

# %% [markdown]
# ['key', 'type', 'seed', 'title', 'title_suggest', 'title_sort', 'edition_count', 'edition_key', 'publish_date', 'publish_year', 'first_publish_year', 'number_of_pages_median', 'isbn', 'last_modified_i', 'ebook_count_i', 'ebook_access', 'has_fulltext', 'public_scan_b', 'readinglog_count', 'want_to_read_count', 'currently_reading_count', 'already_read_count', 'publisher', 'language', 'author_key', 'author_name', 'author_alternative_name', 'publisher_facet', '_version_', 'author_facet']

# %%
data['docs'][0]['title'] # title
# Out:
# 'Herland Illustrated'

# %%
data['docs'][0]['edition_count'] # editions
# Out:
# 104

# %%
# data['docs'][0]['edition_key'] # key for each edition
display(len(data['docs'][0]['edition_key']))
# Out:
# 104

# %%
data['docs'][0]['first_publish_year'] # first_publish_date
# Out:
# 2019

# %%
data['docs'][0]['publish_year'] # publish_year
# Out:
# [2019, 2020, 2021, 2022]

# %%
data['docs'][0]['number_of_pages_median'] # pages
# Out:
# 195

# %%
#data['docs'][0]['isbn'] # ISBN
len(data['docs'][0]['isbn'])
# Out:
# 105

# %%
data['docs'][0]['last_modified_i']
# Out:
# 1658517449

# %%
data['docs'][0]['ebook_count_i']
# Out:
# 0

# %%
data['docs'][0]['ebook_access']
# Out:
# 'no_ebook'

# %%
data['docs'][0]['has_fulltext']
# Out:
# False

# %%
data['docs'][0]['public_scan_b']
# Out:
# False

# %%
data['docs'][0]['readinglog_count']
# Out:
# 6

# %%
data['docs'][0]['want_to_read_count']
# Out:
# 6

# %%
data['docs'][0]['currently_reading_count']
# Out:
# 0

# %%
data['docs'][0]['already_read_count']
# Out:
# 0

# %%
data['docs'][0]['publisher']
# Out:
# ['Independently Published']

# %%
data['docs'][0]['language']
# Out:
# ['eng']

# %%
data['docs'][0]['author_key']
# Out:
# ['OL408063A']

# %%
data['docs'][0]['author_name']
# Out:
# ['Charlotte Perkins Gilman']

# %%
data['docs'][0]['author_alternative_name']
# Out:
# ['Gilman, Charlotte Perkins',
#  'Charlotte perkins Gilman',
#  'Charlotte Perkins Perkins Gilman',
#  'Charlotte Perkins Gilman Gilman',
#  'Charlotte Perkins Stetson Gilman',
#  'CHARLOTTE PERKINS GILMAN',
#  'Charlotte Perkins 1860-1935 Gilman',
#  'Perkins Gilman',
#  'Charlotte P. Gilman',
#  'Charlotte Gilman',
#  'Gilman, Charlotte Perkins 1860-1935.',
#  'Charlotte Perkins, Gilman,',
#  'Charlotte, Perkins Gilman',
#  'Charlotte, Perkins Stetson Gilman',
#  'Charlotte (Perkins) Steton Gilman']

# %%
data['docs'][0]['publisher_facet']
# Out:
# ['Independently Published']

# %%
data['docs'][0]['_version_']
# Out:
# 1759765126443958272

# %%
data['docs'][0]['author_facet']
# Out:
# ['OL408063A Charlotte Perkins Gilman']

# %%
def get_open_library_data(query):
    # Set the base URL for the Open Library search API
    base_url = 'http://openlibrary.org/search.json'

    # Initialize the list of books
    books = []

    # Set the page number to 1
    page_num = 1

    # Keep looping until we have retrieved all the books
    while True:
        # Set the query parameters for the API request
        params = {'q': query, 'page': page_num}

        # Make the API request
        response = requests.get(base_url, params=params)

        # Check if the API request was successful
        if response.status_code == 200:
            # Parse the JSON response
            data = json.loads(response.text)

            # Loop over each book in the response and extract the desired information
            for book in data['docs']:
                # Get the book title
                title = book.get('title')

                # Get the book author(s)
                author = book.get('author_name')

                # Get the year of the first publication
                publish_date = None
                if 'first_publish_year' in book:
                    publish_date = int(book['first_publish_year'])

                # Get the ISBN-13 number
                isbn_13 = book.get('isbn', [])[0] if 'isbn' in book else None

                # Get the URL for the book's JSON data
                book_url = book.get('key') + '.json'

                # Check if the book URL is a valid URL
                if not book_url.startswith('http'):
                    continue

                # Make a request for the book's JSON data
                book_response = requests.get(book_url)

                # Check if the request was successful
                if book_response.status_code == 200:
                    # Parse the JSON data
                    book_data = json.loads(book_response.text)

                    # Get the book's description
                    description = book_data.get('description', None)

                    # Get the book's rating and number of pages
                    details = book_data.get('details', {})
                    average_rating = details.get('average_rating', None)
                    num_pages = details.get('number_of_pages', None)

                    # Get the book's price, if available
                    price = None
                    for item in book_data.get('items', []):
                        if 'price' in item:
                            price = item['price']
                            break

                    # Get the book's awards, if available
                    awards = book_data.get('awards', None)

                # Add the book information to the list of books
                books.append({
                    'Title': title,
                    'Author': author,
                    'ISBN_13': isbn_13,
                    'Publish_Date': publish_date,
                    'Description': description,
                    'Average_Rating': average_rating,
                    'Number_of_Pages': num_pages,
                    'Price': price,
                    'Awards': awards
                })

                # Add a random sleep time between 1 and 3 seconds to avoid overwhelming the Open Library API
                time.sleep(random.randint(1, 3))

            # Check if we have reached the end of the list of books
            if len(books) >= data['num_found']:
                break

            # Increment the page number
            page_num += 1
        else:
            # If the API request was not successful, print an error message
            print(f"Error: API request failed with status code {response.status_code}")
            return None

    # Return the list of books
    return books
