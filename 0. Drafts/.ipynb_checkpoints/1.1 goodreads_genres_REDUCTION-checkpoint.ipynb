# %%
import pandas as pd

# %%
gr_data = pd.read_csv('GoodReads-Copy1.Best_Books_Ever 2.csv')

# %%
display(gr_data.head(2),gr_data.shape)
# Out:
#                                        title               series  \
# 0                           The Hunger Games  The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix      Harry Potter #5
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
#
#                                          description language         isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English  9.78044E+12
# 1  There is a door at the end of a silent corrido...  English  9.78044E+12
#
#                                               genres  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
#
#                                           characters bookFormat  ...  \
# 0  ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  Hardcover  ...
# ...

# %% [markdown]
# #### Unique genres count

# %%
# Define an empty list to store the genres
genres_list = []

# Loop through all rows of genres
for i in range(len(gr_data)):
    # Get the genres for the current row
    genres_row = gr_data['genres'][i]

    # Remove the square brackets and single quotes
    genres_row = genres_row.replace('[','').replace(']','').replace("'",'')

    # Split the row into individual genres
    genres = genres_row.split(',')

    # Loop through each genre in the row
    for genre in genres:
        # Clean up the genre by removing any extra whitespace and converting to title case
        genre = genre.strip().title()
        # Check if the genre is not empty and not already in the genres_list
        if genre and genre not in genres_list:
            # If it contains non-ASCII characters, skip it
            if any(ord(c) > 127 for c in genre):
                continue
            # If it's not in the genres_list, add it
            else:
                genres_list.append(genre)

# Print the final genres list and its length
print("Length of uniques genres:",len(genres_list))
#print("Length of uniques genres after cleaning: from 980 to",len(genres_list))
#print("")
#print(genres_list)
# Out:
# Length of uniques genres: 980

# %%
# Frequency
genre_counts = []

for genre in genres_list:
    count = gr_data['genres'].apply(lambda x: genre in x).sum()
    genre_counts.append((genre, count))

genre_counts = sorted(genre_counts, key=lambda x: x[1], reverse=True)

for genre, count in genre_counts:
    print(f"{genre}: {count}")
# Out:
# Fiction: 33615
# Adult: 20481
# Roman: 16575
# Romance: 15793
# Fantasy: 15321
# Young Adult: 11878
# Contemporary: 10713
# Literature: 10365
# Novels: 9621
# Historical: 8954
# Nonfiction: 8251
# Science: 8126
# Mystery: 7782
# Historical Fiction: 7666
# Audiobook: 7307
# Class: 6943
# Classics: 6935
# Science Fiction: 6610
# Adventure: 6455
# Paranormal: 6093
# Childrens: 5226
# Thriller: 5204
# Magic: 4817
# Humor: 4227
# History: 4184
# Crime: 3766
# Contemporary Romance: 3624
# Suspense: 3593
# Urban: 3562
# Urban Fantasy: 3464
# Middle Grade: 3389
# Chick Lit: 3358
# Science Fiction Fantasy: 3302
# Biography: 3227
# Supernatural: 3196
# Mystery Thriller: 3094
# American: 2934
# Paranormal Romance: 2912
# Horror: 2907
# Teen: 2795
# Philosophy: 2761
# Adult Fiction: 2753
# Stories: 2676
# Memoir: 2636
# School: 2618
# Short Stories: 2613
# Literary Fiction: 2522
# British Literature: 2471
# Realistic Fiction: 2449
# Drama: 2419
# Religion: 2306
# New Adult: 2301
# War: 2273
# ...

# %% [markdown]
# #### Reducing genres

# %%
categories = {
    
    "Gothic" : ['Goth'],
    
    "Plants" : ['Plantagenet'],
    
    "Alternative Medicine" : ['Naturopathy'],
    
    "Mistery": ['Whodunit','Golden Age Mystery'],
    
    "Maps and Cartography" : ['Maps','Cartography','Atlases'],
    
    "Astronomy" : ['Planets'],
    
    "Mythology and Fairy Tales": ['Cryptids', 'Goddess','Fractured Fairy Tales','Fables',
                                 'Folk Tales','Gods','Fairy Tale Retellings'],
    
    'TV and Series' : ['Babylon 5','Tv'],
    
    'Mathematics' : ['Algebra', 'Geometry'],
    
    'Veganism and Vegetarianism': ['Vegetarianism'],
    
    'Medicine' : ['History Of Medicine','Paramedics', 'Vaccines'],
    
    'Cars and Motorcycles': ['Motorcycling','Cars','Motorcycle'],
    
    'Business and Finance' : ['Human Resources','Taxation','Banking','Finance','Banks'],
    
    'Personal Growth' : ['Money Management', 'Growth Mindset'], 

    'Religion Studies': ['Atheism','God', 'Church History','Islamism','Ecclesiology',
                         'Fundamentalism', 'Faith','Theology','Church', 'Belief',
                         'Theosophy'],
    
    'Christianity' : ['Christian','Catholic','Biblical','Scripture','Old Testament',
                     'New Testament','Evangelism','Christian Living','Christian Non Fiction',
                     'Christian Fantasy','Lds Non Fiction','Christian Historical Fiction',
                     'Lds','Lds Fiction', 'Biblical Fiction'],
    
    'Judaism' : ['Judaism','Jewish'],
    
    'Islam' : ['Muslims','Muslimah'],
    
    'Eastern Religions and Faith': ['Hinduism','Taoism', 'Buddhism'],
    
    'Fiction' : ['Literary Fiction', 'Realistic Fiction', 'American Fiction', 'Novella'],
    
    'Esoterica' : ['Spirituality','Mysticisim','Divination','Pseudoscience','Astrology',
                   'Spiritualism','Occult','Numerology', 'Tarot','Thelema'],
    
    'Science Fiction' : ['Science Fiction Fantasy', 'High Fantasy', 'Supernatural',
                         'Post Apocalyptic'],
    
    'Young Adult' : ['teen','Juvenile','Adolescence', 'M M Young Adult', 'Teen',
                     'Young Adult Romance'],
    
    'Adult' : ['New Adult', 'Adult Fiction'],
    
    'Memoires and Biographies' : ['Biography Memoir', 'Autobiography', 'Memoir', 'Biography'],
    
    'School' : ['Read For School','Back To School','Homeschool','2Nd Grade','1St Grade',
                'School Stories','Grad School','High School','Middle Grade','Textbooks',
                'Read For College'],
    
    'Romance' : ['Roman', 'Romantic','Clean Romance','Category Romance'],
    
    'Humor' : ['Jokes', 'Comedian'],
    
    'Classics' : ['Classic Literature', 'Modern Classics', 'Children Classics',
                  'Cult Classics','Beauty And The Beast'],

    'Children' : ['Kids', 'Childrens','Young Readers','Pre K'],
    
    'Erotica' : ['Erotic Romance','Erotic Historical Romance','Pornography','Sex Work',
                 'Loveswept', 'Strippers','Gay Erotica','Bdsm','M F M', 'Fandom',
                 'M M F','M M M','Intersex', 'Nsfw','Menage','M F Romance','Omegaverse'],
    
    'Graphic Novel and Comics' : ['Graphic Novels', 'Comics', 'Graphic Novels Comics',
                                  'Comic Book', 'Comic Strips', 'Comics Manga', 'Comix',
                                  'Graphic Novels Manga','Dc Comics', 'Comics Bd'],
    
    'African American Literature' : ['African American Romance','African American'],
    
    'North American Countries' : ['Canada', 'American','United States'],
    
    'North American Literature' : ['Canadian Literature'],
    
    'South American Countries' : ['Brazil','Bolivia'],
    
    'African Countries' : ['Egypt', 'Nigeria','South Africa', 'Ethiopia', 'Botswana',
                           'Liberia', 'Sierra Leone', 'Sudan','Kenya', 'Somalia', 'Morocco',
                           'Algeria','Ghana', 'Rwanda','Zimbabwe','Sao Tome And Principe',
                           'Burundi','Malawi','Togo', 'Mozambique','Eritrea','Tanzania',
                           'Zambia','Namibia','Uganda','Ivory Coast','Republic Of The Congo',
                           'Benin','Senegal','Guinea'],
    
    'African Literature' : ['Egyptian Literature', 'Northern Africa','Central Africa',
                            'Eastern Africa', 'Western Africa'],
    
    'Asian countries' : ['Japan', 'India', 'China', 'Pakistan', 'Iran', 'Lebanon',
                         'Kazakhstan','Bangladesh'],
    
    'Asian Literature' : ['Japanese Literature', 'Indian Literature', 'Turkish Literature',
                          'Turkish', 'Indonesian Literature','Chinese Literature'],
    
    'European Countries' : ['France', 'Russia', 'Scotland', 'Sweden', 'Spain', 'Italy',
                            'Denmark','Poland', 'Ukraine','Belgium','Hungary','Bulgaria',
                            'Romania'],
    
    'European Literature' : ['British Literature', 'French Literature', 'Russian Literature',
                             'Irish Literature', 'German Literature', 'Czech Literature',
                             'Italian Literature', 'Scandinavian Literature',
                             'English Literature', 'Swedish Literature', 'Danish',
                             'Polish Literature', 'Serbian Literature', 'Finnish Literature',
                             'Dutch Literature', 'Bulgarian Literature','Romanian Literature',
                             'Hungarian Literature', 'Belgian','Anglo Saxon','Georgian',
                             'Albanian Literature', 'Ukrainian Literature'],
    
    'Iberoamerican Literature' : ['Spanish Literature', 'Latin American', 'Esp',
                                  'Portuguese Literature', 'Latin American Literature'],
    
    'Literature' : ['Books About Books','Book Club','Novella','International Literature',
                    'Multicultural Literature','Librarianship','Book Club','Geoffrey Chaucer'],
    
    'Gastronomy, Food and Nutrition' : ['Food','Cooking','Nutrition','Foodie','Cookbooks',
                                        'Culinary', 'Diets','Food Writing','Food History',
                                        'Cocktails','Gastronomy', 'Cuisine',
                                        'Food Preservation','Food And Drink'],
    
    'Music and Musicians' : ['Space Opera','Musicians','Music Biography'],

    'Science' : ['Environment','Popular Science', 'History Of Science', 'Science Nature',
                 'Library Science','Earth Sciences','Nature', 'Field Guides'],
    
    'Animals' : ['Dogs','Horses','Wolves','Cats''Rabbits'],
    
    'Guides and Travel' : ['Travelogue','Road Trip','Guidebook','Guides'],
    
    'Philosophy' : ['Eastern Philosophy','Skepticism','Metaphysics','Logic','Criticism',
                    'Semiotics'],
    
    'LGTBI and Queer' : ['Queer','Gay','Lesbian','Transgender','Queer Lit','Gay For You',
                         'Boys Love', 'Genderqueer','Bisexual','Butch Femme','Queer Studies',
                         'Lgbt','Cross Dressing'],
    
    'Gaming' : ['Gaming','Games','Game Design','Warcraft','World Of Warcraft','Mmorpg',
                'Video Games'],
    
    'Linguistics' : ['Language','Words'],
    
    'Programming and Computer Science' : ['Software','Coding','Computer Science',
                                          'Game Design','Programming','Computers',
                                          'Geek','Hackers','Internet','Google','Apple',
                                          'Web','Algorithms'],
    
    'Gender Studies' : ['Gender And Sexuality','Gender Studies','Womens Studies'],
    
    'Climate Change' : ['Global Warming'],
    
    'Art and Photography' : ['Art', 'Art History','Art Design','Sequential Art','Visual Art',
                            'Pre Raphaelite','Colouring Books', 'Street Art'],
    
    'Social Justice and Activism' : ['Social Issues','Activism','Anti Racist','Social Work',
                                     'Disability Studies','Social Change','Social Movements',
                                     'Social Justice', 'Far Right', 'Foster Children',
                                     'Foster Parents'],
    
    'Harlequin' : ['Harlequin Teen','Harlequin Heartwarming','Harlequin Romance',
                   'Harlequin Desire','Harlequin Historical','Harlequin Blaze',
                   'Harlequin Presents','Harlequin Nocturne'],
    
    'Sewing and Crafts' : ['Knitting','Quilting','Jewellery', 'Woodwork'],
    
    'Diary and Journal' : ['Diary', 'Diaries','Journaling'],
    
    'Fat Studies' : ['Fat Acceptance','Fat','Plus Size'],
    
    'Urban Studies' : ['Urbanism'],
    
    'Magic' : ['Magick'],
    
    'Aircraft' : ['Airships','Aeroplanes']
}

# %%
import ast 

for i in range(len(gr_data['genres'])):
    genre_list_str = gr_data['genres'][i]
    genre_list = ast.literal_eval(genre_list_str)

    for j in range(len(genre_list)):
        for key, lst in categories.items():
            if genre_list[j] in lst:
                genre_list[j] = key

    gr_data['genres'][i] = str(genre_list)
# Out:
# /var/folders/w7/7cfd14hn02g0d126w5q47rqw0000gn/T/ipykernel_8402/2514504838.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gr_data['genres'][i] = str(genre_list)

# %% [markdown]
# #### First genres reduction count

# %%
# Define an empty list to store the genres
genres_list = []

# Loop through all rows of genres
for i in range(len(gr_data)):
    # Get the genres for the current row
    genres_row = gr_data['genres'][i]

    # Remove the square brackets and single quotes
    genres_row = genres_row.replace('[','').replace(']','').replace("'",'')

    # Split the row into individual genres
    genres = genres_row.split(',')

    # Loop through each genre in the row
    for genre in genres:
        # Clean up the genre by removing any extra whitespace and converting to title case
        genre = genre.strip().title()
        # Check if the genre is not empty and not already in the genres_list
        if genre and genre not in genres_list:
            # If it contains non-ASCII characters, skip it
            if any(ord(c) > 127 for c in genre):
                continue
            # If it's not in the genres_list, add it
            else:
                genres_list.append(genre)

# Print the final genres list and its length
#print("Length of uniques genres:",len(genres_list))
print("Length of uniques genres after cleaning: from 980 to",len(genres_list))
print("")
#print(genres_list)
# Out:
# Length of uniques genres after cleaning: from 980 to 654

# %%
# Frequency
genre_counts = []

for genre in genres_list:
    count = gr_data['genres'].apply(lambda x: genre in x).sum()
    genre_counts.append((genre, count))

genre_counts = sorted(genre_counts, key=lambda x: x[1], reverse=True)

for genre, count in genre_counts:
    print(f"{genre}: {count}")
# Out:
# Fiction: 34281
# Adult: 20913
# Romance: 16426
# Fantasy: 15106
# Young Adult: 12321
# Science: 11756
# Literature: 11409
# Contemporary: 10713
# Science Fiction: 9935
# Historical: 8954
# Nonfiction: 8251
# Novels: 7807
# Mystery: 7782
# Historical Fiction: 7665
# Audiobook: 7307
# Class: 6943
# Classics: 6936
# Adventure: 6455
# Paranormal: 6093
# School: 5669
# European Literature: 5402
# Children: 5228
# Thriller: 5204
# Magic: 4817
# Humor: 4227
# History: 4142
# Crime: 3766
# Contemporary Romance: 3624
# Suspense: 3593
# Urban: 3562
# Urban Fantasy: 3464
# Chick Lit: 3358
# Mystery Thriller: 3094
# European Countries: 3046
# Paranormal Romance: 2912
# Horror: 2907
# Philosophy: 2848
# Stories: 2657
# Short Stories: 2613
# Religion: 2486
# Drama: 2419
# North American Countries: 2345
# War: 2264
# Erotica: 2249
# Christianity: 2139
# Asia: 2032
# Vampires: 1947
# Politics: 1767
# Family: 1706
# Dystopia: 1692
# Psychology: 1610
# Poetry: 1595
# Esoterica: 1531
# Travel: 1508
# ...

# %% [markdown]
# #### Removing Genres < 2 counts

# %%
# Unique genres with just for 1 book
genres_with_less_2 = [genre[0] for genre in genre_counts if genre[1] < 2]

len(genres_with_less_2)
#genres_with_less_2
# Out:
# 84

# %%
for i in range(len(gr_data['genres'])):
    genre_list_str = gr_data['genres'][i]
    genre_list = ast.literal_eval(genre_list_str)

    # Remove genres with zero count from genre_list
    for genre_with_less_2 in genres_with_less_2:
        if genre_with_less_2 in genre_list:
            genre_list.remove(genre_with_less_2)

    gr_data['genres'][i] = str(genre_list)
# Out:
# /var/folders/w7/7cfd14hn02g0d126w5q47rqw0000gn/T/ipykernel_8402/1791325191.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gr_data['genres'][i] = str(genre_list)

# %%
# Define an empty list to store the genres
genres_list = []

# Loop through all rows of genres
for i in range(len(gr_data)):
    # Get the genres for the current row
    genres_row = gr_data['genres'][i]

    # Remove the square brackets and single quotes
    genres_row = genres_row.replace('[','').replace(']','').replace("'",'')

    # Split the row into individual genres
    genres = genres_row.split(',')

    # Loop through each genre in the row
    for genre in genres:
        # Clean up the genre by removing any extra whitespace and converting to title case
        genre = genre.strip().title()
        # Check if the genre is not empty and not already in the genres_list
        if genre and genre not in genres_list:
            # If it contains non-ASCII characters, skip it
            if any(ord(c) > 127 for c in genre):
                continue
            # If it's not in the genres_list, add it
            else:
                genres_list.append(genre)

# Print the final genres list and its length
#print("Length of uniques genres:",len(genres_list))
print("Length of uniques genres after cleaning: from 980 to",len(genres_list))
print("")
#print(genres_list)
# Out:
# Length of uniques genres after cleaning: from 980 to 617

# %%
# Frequency
genre_counts = []

for genre in genres_list:
    count = gr_data['genres'].apply(lambda x: genre in x).sum()
    genre_counts.append((genre, count))

genre_counts = sorted(genre_counts, key=lambda x: x[1], reverse=True)

for genre, count in genre_counts:
    print(f"{genre}: {count}")
# Out:
# Fiction: 34281
# Adult: 20913
# Romance: 16426
# Fantasy: 15106
# Young Adult: 12321
# Science: 11756
# Literature: 11409
# Contemporary: 10713
# Science Fiction: 9935
# Historical: 8954
# Nonfiction: 8251
# Novels: 7807
# Mystery: 7782
# Historical Fiction: 7665
# Audiobook: 7307
# Class: 6942
# Classics: 6936
# Adventure: 6455
# Paranormal: 6093
# School: 5669
# European Literature: 5402
# Children: 5228
# Thriller: 5204
# Magic: 4817
# Humor: 4227
# History: 4142
# Crime: 3766
# Contemporary Romance: 3624
# Suspense: 3593
# Urban: 3562
# Urban Fantasy: 3464
# Chick Lit: 3358
# Mystery Thriller: 3094
# European Countries: 3046
# Paranormal Romance: 2912
# Horror: 2907
# Philosophy: 2848
# Stories: 2657
# Short Stories: 2613
# Religion: 2486
# Drama: 2419
# North American Countries: 2345
# War: 2263
# Erotica: 2249
# Christianity: 2139
# Asia: 2032
# Vampires: 1947
# Politics: 1767
# Family: 1706
# Dystopia: 1692
# Psychology: 1610
# Poetry: 1595
# Esoterica: 1531
# Travel: 1508
# ...

# %%
# Unsuccesful attempt to drop genres with 0 counts

import ast 

# Set of genres to delete from the lists
to_delete = {'World War Ii', '19Th Century', 'Lgbt', '20Th Century', 'Bdsm', '18Th Century',
             'Beauty And The Beast', '14Th Century', '15Th Century', '16Th Century', 
             'Sword And Sorcery', 'Dungeons And Dragons', '17Th Century', '21St Century',
             '13Th Century', '12Th Century', 'Sao Tome And Principe', 'Food And Drink',
             'History And Politics', 'Sword And Planet', 'Art And Photography', '2Nd Grade',
             '40K', '1St Grade', 'Nsfw', 'Mills And Boon', 'Gender And Sexuality', 
             '11Th Century', '10Th Century'}

# Loop over each genre list in gr_data['genres']
for i in range(len(gr_data['genres'])):
    # Extract the genre list string and convert it to a Python list
    genre_list_str = gr_data['genres'][i]
    genre_list = ast.literal_eval(genre_list_str)

    # Remove any genres from the genre list that appear in to_delete
    genre_list = [genre for genre in genre_list if genre not in to_delete]

    # Map each genre in the genre list to a category
    for j in range(len(genre_list)):
        for key, lst in categories.items():
            if genre_list[j] in lst:
                genre_list[j] = key

    # Convert the modified genre list back to a string and assign it to gr_data['genres'][i]
    gr_data['genres'][i] = str(genre_list)
# Out:
# /var/folders/w7/7cfd14hn02g0d126w5q47rqw0000gn/T/ipykernel_8402/1174348026.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gr_data['genres'][i] = str(genre_list)

# %%
# Define an empty list to store the genres
genres_list = []

# Loop through all rows of genres
for i in range(len(gr_data)):
    # Get the genres for the current row
    genres_row = gr_data['genres'][i]

    # Remove the square brackets and single quotes
    genres_row = genres_row.replace('[','').replace(']','').replace("'",'')

    # Split the row into individual genres
    genres = genres_row.split(',')

    # Loop through each genre in the row
    for genre in genres:
        # Clean up the genre by removing any extra whitespace and converting to title case
        genre = genre.strip().title()
        # Check if the genre is not empty and not already in the genres_list
        if genre and genre not in genres_list:
            # If it contains non-ASCII characters, skip it
            if any(ord(c) > 127 for c in genre):
                continue
            # If it's not in the genres_list, add it
            else:
                genres_list.append(genre)

# Print the final genres list and its length
#print("Length of uniques genres:",len(genres_list))
print("Length of uniques genres after cleaning: from 980 to",len(genres_list))
print("")
#print(genres_list)
# Out:
# Length of uniques genres after cleaning: from 980 to 617

# %% [markdown]
# #### Dealing with new genre lists

# %%
# Problem with duplicates
gr_data['genres'][0]
# Out:
# "['Young Adult', 'Fiction', 'Dystopia', 'Fantasy', 'Science Fiction', 'Romance', 'Adventure', 'Young Adult', 'Science Fiction', 'Action']"

# %%
# Removing duplicates -- set()

# Using the set() function: Convert the list to a set, which automatically removes duplicates,
# and then convert the set back to a list. This method does not preserve the order
# of the original list.

for i in range(len(gr_data['genres'])):
    genre_list_str = gr_data['genres'][i]
    genre_list = ast.literal_eval(genre_list_str)

    # Remove duplicates
    genre_list = list(set(genre_list))

    gr_data['genres'][i] = str(genre_list)
# Out:
# /var/folders/w7/7cfd14hn02g0d126w5q47rqw0000gn/T/ipykernel_8402/4198679187.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gr_data['genres'][i] = str(genre_list)

# %%
# Checking no duplicates present
gr_data['genres'][0]
# Out:
# "['Fantasy', 'Science Fiction', 'Dystopia', 'Young Adult', 'Fiction', 'Action', 'Adventure', 'Romance']"

# %%
gr_data.to_csv('gr_data_genre_modified.csv')
