# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

# %% [markdown]
# ## Fiction Winners

# %%
# Send a GET request to the URL
url = 'https://en.wikipedia.org/wiki/Pulitzer_Prize_for_Fiction'
response = requests.get(url)
display(response.status_code)
# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')
# Out:
# 200

# %%
# Parse the HTML content using BeautifulSoup
#soup = BeautifulSoup(response.content, 'html.parser')
#print(soup.prettify())

# %% [markdown]
# ### Table 1918-1978

# %%
#soup.select('#mw-content-text > div.mw-parser-output > table:nth-child(24)')

# %%
winners = soup.select("table")[1]
#winners

# %% [markdown]
# #### Year and Book Title 1918 to 1979

# %% [markdown]
# #mw-content-text > div.mw-parser-output > table:nth-child(24) > tbody > tr:nth-child(1) > td:nth-child(1) > b > a

# %%
winners.select('tr td b a')[1]['title']
# Out:
# 'His Family'

# %%
titles = []
for name in winners.select('tr td b a'):
    book = name.get('title')
    titles.append(name['title'])
    
titles[0:10]
# Out:
# ['1917 in literature',
#  'His Family',
#  '1918 in literature',
#  'The Magnificent Ambersons',
#  '1919 in literature',
#  '1920 in literature',
#  'The Age of Innocence',
#  '1921 in literature',
#  'Alice Adams (novel)',
#  '1922 in literature']

# %%
len(titles)
# Out:
# 115

# %%
# Adding NaN to empty winner books

# Loop through the titles list
i = 0
while i < len(titles)-1:
    # Check if two consecutive titles both contain the phrase 'in literature'
    if 'in literature' in titles[i] and 'in literature' in titles[i+1]:
        # If they do, insert a 'NaN' in between them
        titles.insert(i+1, 'NaN')
        i += 2
    else:
        # If not, move on to the next title
        i += 1

display(titles[0:15], len(titles))
# Out:
# ['1917 in literature',
#  'His Family',
#  '1918 in literature',
#  'The Magnificent Ambersons',
#  '1919 in literature',
#  'NaN',
#  '1920 in literature',
#  'The Age of Innocence',
#  '1921 in literature',
#  'Alice Adams (novel)',
#  '1922 in literature',
#  'One of Ours',
#  '1923 in literature',
#  'The Able McLaughlins',
#  '1924 in literature']
# 124

# %%
# Checking that there's at least one different row in between 'in literature' rows
has_different_row = False
for i in range(len(titles)-2):
    if 'in literature' in titles[i] and 'in literature' in titles[i+2]:
        has_different_row = True
        break

print(has_different_row)
# Out:
# True

# %%
# Generating first dataframe

years = []
books = []

# Loop through the titles list and separate the years and book titles
for i in range(len(titles)):
    # Every other element contains a year
    if i % 2 == 0:
        years.append(titles[i])
    # Every other element contains a book title
    else:
        books.append(titles[i])

# Combine the two lists into a DataFrame
pulitzer_fiction = pd.DataFrame({
    'year': years,
    'book': books
})

# Print the resulting DataFrame
pulitzer_fiction
# Out:
#                   year                                            book
# 0   1917 in literature                                      His Family
# 1   1918 in literature                       The Magnificent Ambersons
# 2   1919 in literature                                             NaN
# 3   1920 in literature                            The Age of Innocence
# 4   1921 in literature                             Alice Adams (novel)
# 5   1922 in literature                                     One of Ours
# 6   1923 in literature                            The Able McLaughlins
# 7   1924 in literature                                  So Big (novel)
# 8   1925 in literature                              Arrowsmith (novel)
# 9   1926 in literature                                    Early Autumn
# 10  1927 in literature                      The Bridge of San Luis Rey
# 11  1928 in literature                             Scarlet Sister Mary
# 12  1929 in literature                            Laughing Boy (novel)
# 13  1930 in literature                                  Years of Grace
# 14  1931 in literature                                  The Good Earth
# 15  1932 in literature                               The Store (novel)
# 16  1933 in literature                               Lamb in His Bosom
# 17  1934 in literature                                 Now in November
# 18  1935 in literature                               Honey in the Horn
# 19  1936 in literature                      Gone with the Wind (novel)
# 20  1937 in literature                           The Late George Apley
# 21  1938 in literature                                    The Yearling
# 22  1939 in literature                             The Grapes of Wrath
# 23  1940 in literature                                             NaN
# 24  1941 in literature                        In This Our Life (novel)
# 25  1942 in literature                          Dragon's Teeth (novel)
# 26  1943 in literature                             Journey in the Dark
# 27  1944 in literature                        A Bell for Adano (novel)
# 28  1945 in literature                                             NaN
# 29  1946 in literature                              All the King's Men
# 30  1947 in literature                      Tales of the South Pacific
# 31  1948 in literature                                  Guard of Honor
# 32  1949 in literature                                    The Way West
# 33  1950 in literature                        The Town (Richter novel)
# 34  1951 in literature                                The Caine Mutiny
# 35  1952 in literature                         The Old Man and the Sea
# 36  1953 in literature                                             NaN
# 37  1954 in literature                                         A Fable
# 38  1955 in literature                           Andersonville (novel)
# 39  1956 in literature                                             NaN
# 40  1957 in literature                           A Death in the Family
# 41  1958 in literature                The Travels of Jaimie McPheeters
# 42  1959 in literature                              Advise and Consent
# 43  1960 in literature                           To Kill a Mockingbird
# 44  1961 in literature                             The Edge of Sadness
# 45  1962 in literature                                     The Reivers
# 46  1963 in literature                                             NaN
# 47  1964 in literature                        The Keepers of the House
# 48  1965 in literature  The Collected Stories of Katherine Anne Porter
# 49  1966 in literature                               The Fixer (novel)
# 50  1967 in literature                   The Confessions of Nat Turner
# 51  1968 in literature                              House Made of Dawn
# 52  1969 in literature          The Collected Stories of Jean Stafford
# 53  1970 in literature                                             NaN
# 54  1971 in literature                                 Angle of Repose
# 55  1972 in literature                         The Optimist's Daughter
# 56  1973 in literature                                             NaN
# 57  1974 in literature                               The Killer Angels
# 58  1975 in literature                                 Humboldt's Gift
# 59  1976 in literature                                             NaN
# 60  1977 in literature             Elbow Room (short story collection)
# 61  1978 in literature                     The Stories of John Cheever

# %%
# Clean up values
pulitzer_fiction['year'] = pulitzer_fiction['year'].str.replace(' in literature', '')
pulitzer_fiction['book'] = pulitzer_fiction['book'].str.replace('\(.*\)', '', regex=True).str.strip()

#pulitzer_fiction

# %%
# Correcting awards year

# Convert 'year' to numeric and add 1
pulitzer_fiction['year'] = pd.to_numeric(pulitzer_fiction['year'])
pulitzer_fiction['year'] += 1

# display dataframe
pulitzer_fiction
# Out:
#     year                                            book
# 0   1918                                      His Family
# 1   1919                       The Magnificent Ambersons
# 2   1920                                             NaN
# 3   1921                            The Age of Innocence
# 4   1922                                     Alice Adams
# 5   1923                                     One of Ours
# 6   1924                            The Able McLaughlins
# 7   1925                                          So Big
# 8   1926                                      Arrowsmith
# 9   1927                                    Early Autumn
# 10  1928                      The Bridge of San Luis Rey
# 11  1929                             Scarlet Sister Mary
# 12  1930                                    Laughing Boy
# 13  1931                                  Years of Grace
# 14  1932                                  The Good Earth
# 15  1933                                       The Store
# 16  1934                               Lamb in His Bosom
# 17  1935                                 Now in November
# 18  1936                               Honey in the Horn
# 19  1937                              Gone with the Wind
# 20  1938                           The Late George Apley
# 21  1939                                    The Yearling
# 22  1940                             The Grapes of Wrath
# 23  1941                                             NaN
# 24  1942                                In This Our Life
# 25  1943                                  Dragon's Teeth
# 26  1944                             Journey in the Dark
# 27  1945                                A Bell for Adano
# 28  1946                                             NaN
# 29  1947                              All the King's Men
# 30  1948                      Tales of the South Pacific
# 31  1949                                  Guard of Honor
# 32  1950                                    The Way West
# 33  1951                                        The Town
# 34  1952                                The Caine Mutiny
# 35  1953                         The Old Man and the Sea
# 36  1954                                             NaN
# 37  1955                                         A Fable
# 38  1956                                   Andersonville
# 39  1957                                             NaN
# 40  1958                           A Death in the Family
# 41  1959                The Travels of Jaimie McPheeters
# 42  1960                              Advise and Consent
# 43  1961                           To Kill a Mockingbird
# 44  1962                             The Edge of Sadness
# 45  1963                                     The Reivers
# 46  1964                                             NaN
# 47  1965                        The Keepers of the House
# 48  1966  The Collected Stories of Katherine Anne Porter
# 49  1967                                       The Fixer
# 50  1968                   The Confessions of Nat Turner
# 51  1969                              House Made of Dawn
# 52  1970          The Collected Stories of Jean Stafford
# 53  1971                                             NaN
# 54  1972                                 Angle of Repose
# 55  1973                         The Optimist's Daughter
# 56  1974                                             NaN
# 57  1975                               The Killer Angels
# 58  1976                                 Humboldt's Gift
# 59  1977                                             NaN
# 60  1978                                      Elbow Room
# 61  1979                     The Stories of John Cheever

# %%
# Saving dataframe
pulitzer_fiction.to_csv('pulitzer_fiction.csv')

# %% [markdown]
# #### Author, Publisher and Genre

# %%
display(winners.select('tr td a')[0]['title'],
        winners.select('tr td a')[1]['title'],
        winners.select('tr td a')[2]['title'],
        winners.select('tr td a')[3]['title'],
        winners.select('tr td a')[4]['title'],
        winners.select('tr td a')[5]['title'])
# Out:
# '1917 in literature'
# 'Ernest Poole'
# 'His Family'
# 'Macmillan Publishers'
# 'Novel'
# 'Illinois'

# %%
data = []

for winner in winners.select('tr td'):
    for a_tag in winner.select('a'):
        if 'title' in a_tag.attrs:
            data.append(a_tag['title'])

# %%
type(data)
# Out:
# list

# %%
# All data
#data

# %%
# Extracting author
author = []
for i in range(len(data)):
    if 'in literature' in data[i]:
        if i+1 < len(data) and 'in literature' not in data[i+1]:
            author.append(data[i+1])
        else:
            author.append('NaN')

# %%
author
# Out:
# ['Ernest Poole',
#  'Booth Tarkington',
#  'NaN',
#  'Edith Wharton',
#  'Booth Tarkington',
#  'Willa Cather',
#  'Margaret Wilson (novelist)',
#  'Edna Ferber',
#  'Sinclair Lewis',
#  'Louis Bromfield',
#  'Thornton Wilder',
#  'Julia Peterkin',
#  'Oliver La Farge',
#  'Margaret Ayer Barnes',
#  'Pearl S. Buck',
#  'T. S. Stribling',
#  'Caroline Pafford Miller',
#  'Josephine Johnson',
#  'H. L. Davis',
#  'Margaret Mitchell',
#  'John P. Marquand',
#  'Marjorie Kinnan Rawlings',
#  'John Steinbeck',
#  'NaN',
#  'Ellen Glasgow',
#  'Upton Sinclair',
#  'Martin Flavin',
#  'John Hersey',
#  'NaN',
#  'Robert Penn Warren',
#  'James A. Michener',
#  'James Gould Cozzens',
#  'A. B. Guthrie Jr.',
#  'Conrad Richter',
#  'Herman Wouk',
#  'Ernest Hemingway',
#  'NaN',
#  'William Faulkner',
#  'MacKinlay Kantor',
#  'NaN',
#  'James Agee',
#  'Robert Lewis Taylor',
#  'Allen Drury',
#  'Harper Lee',
#  "Edwin O'Connor",
#  'William Faulkner',
#  'NaN',
#  'Shirley Ann Grau',
#  'Katherine Anne Porter',
#  'Bernard Malamud',
#  'William Styron',
#  'N. Scott Momaday',
#  'Jean Stafford',
#  'NaN',
#  'Wallace Stegner',
#  'Eudora Welty',
#  'NaN',
#  'Michael Shaara',
#  'Saul Bellow',
#  'NaN',
#  'James Alan McPherson',
#  'John Cheever']

# %%
# Add 'author' column to the dataframe and append values from 'author' list
pulitzer_fiction['author'] = author
pulitzer_fiction.head(10)
# Out:
#    year                       book                      author
# 0  1918                 His Family                Ernest Poole
# 1  1919  The Magnificent Ambersons            Booth Tarkington
# 2  1920                        NaN                         NaN
# 3  1921       The Age of Innocence               Edith Wharton
# 4  1922                Alice Adams            Booth Tarkington
# 5  1923                One of Ours                Willa Cather
# 6  1924       The Able McLaughlins  Margaret Wilson (novelist)
# 7  1925                     So Big                 Edna Ferber
# 8  1926                 Arrowsmith              Sinclair Lewis
# 9  1927               Early Autumn             Louis Bromfield

# %%
# Adding 'genre' column. All values are 'Novel' except rows with NaN
pulitzer_fiction.loc[pulitzer_fiction['author'] != 'NaN', 'genre'] = 'Novel'
pulitzer_fiction.loc[pulitzer_fiction['author'] == 'NaN', 'genre'] = 'NaN'

# %%
pulitzer_fiction
# Out:
#     year                                            book  \
# 0   1918                                      His Family
# 1   1919                       The Magnificent Ambersons
# 2   1920                                             NaN
# 3   1921                            The Age of Innocence
# 4   1922                                     Alice Adams
# 5   1923                                     One of Ours
# 6   1924                            The Able McLaughlins
# 7   1925                                          So Big
# 8   1926                                      Arrowsmith
# 9   1927                                    Early Autumn
# 10  1928                      The Bridge of San Luis Rey
# 11  1929                             Scarlet Sister Mary
# 12  1930                                    Laughing Boy
# 13  1931                                  Years of Grace
# 14  1932                                  The Good Earth
# 15  1933                                       The Store
# 16  1934                               Lamb in His Bosom
# 17  1935                                 Now in November
# 18  1936                               Honey in the Horn
# 19  1937                              Gone with the Wind
# 20  1938                           The Late George Apley
# 21  1939                                    The Yearling
# 22  1940                             The Grapes of Wrath
# 23  1941                                             NaN
# 24  1942                                In This Our Life
# 25  1943                                  Dragon's Teeth
# 26  1944                             Journey in the Dark
# 27  1945                                A Bell for Adano
# 28  1946                                             NaN
# 29  1947                              All the King's Men
# 30  1948                      Tales of the South Pacific
# 31  1949                                  Guard of Honor
# 32  1950                                    The Way West
# 33  1951                                        The Town
# 34  1952                                The Caine Mutiny
# 35  1953                         The Old Man and the Sea
# 36  1954                                             NaN
# 37  1955                                         A Fable
# 38  1956                                   Andersonville
# 39  1957                                             NaN
# 40  1958                           A Death in the Family
# 41  1959                The Travels of Jaimie McPheeters
# 42  1960                              Advise and Consent
# 43  1961                           To Kill a Mockingbird
# 44  1962                             The Edge of Sadness
# 45  1963                                     The Reivers
# 46  1964                                             NaN
# 47  1965                        The Keepers of the House
# 48  1966  The Collected Stories of Katherine Anne Porter
# 49  1967                                       The Fixer
# 50  1968                   The Confessions of Nat Turner
# 51  1969                              House Made of Dawn
# 52  1970          The Collected Stories of Jean Stafford
# 53  1971                                             NaN
# 54  1972                                 Angle of Repose
# 55  1973                         The Optimist's Daughter
# 56  1974                                             NaN
# 57  1975                               The Killer Angels
# 58  1976                                 Humboldt's Gift
# 59  1977                                             NaN
# 60  1978                                      Elbow Room
# 61  1979                     The Stories of John Cheever
#
#                         author  genre
# 0                 Ernest Poole  Novel
# 1             Booth Tarkington  Novel
# 2                          NaN    NaN
# 3                Edith Wharton  Novel
# 4             Booth Tarkington  Novel
# 5                 Willa Cather  Novel
# 6   Margaret Wilson (novelist)  Novel
# 7                  Edna Ferber  Novel
# 8               Sinclair Lewis  Novel
# 9              Louis Bromfield  Novel
# 10             Thornton Wilder  Novel
# 11              Julia Peterkin  Novel
# 12             Oliver La Farge  Novel
# 13        Margaret Ayer Barnes  Novel
# 14               Pearl S. Buck  Novel
# 15             T. S. Stribling  Novel
# 16     Caroline Pafford Miller  Novel
# 17           Josephine Johnson  Novel
# 18                 H. L. Davis  Novel
# 19           Margaret Mitchell  Novel
# 20            John P. Marquand  Novel
# 21    Marjorie Kinnan Rawlings  Novel
# 22              John Steinbeck  Novel
# 23                         NaN    NaN
# 24               Ellen Glasgow  Novel
# 25              Upton Sinclair  Novel
# 26               Martin Flavin  Novel
# 27                 John Hersey  Novel
# 28                         NaN    NaN
# 29          Robert Penn Warren  Novel
# 30           James A. Michener  Novel
# 31         James Gould Cozzens  Novel
# 32           A. B. Guthrie Jr.  Novel
# 33              Conrad Richter  Novel
# 34                 Herman Wouk  Novel
# 35            Ernest Hemingway  Novel
# 36                         NaN    NaN
# 37            William Faulkner  Novel
# 38            MacKinlay Kantor  Novel
# 39                         NaN    NaN
# 40                  James Agee  Novel
# 41         Robert Lewis Taylor  Novel
# 42                 Allen Drury  Novel
# 43                  Harper Lee  Novel
# 44              Edwin O'Connor  Novel
# 45            William Faulkner  Novel
# 46                         NaN    NaN
# 47            Shirley Ann Grau  Novel
# 48       Katherine Anne Porter  Novel
# 49             Bernard Malamud  Novel
# 50              William Styron  Novel
# 51            N. Scott Momaday  Novel
# 52               Jean Stafford  Novel
# 53                         NaN    NaN
# 54             Wallace Stegner  Novel
# 55                Eudora Welty  Novel
# 56                         NaN    NaN
# 57              Michael Shaara  Novel
# 58                 Saul Bellow  Novel
# 59                         NaN    NaN
# 60        James Alan McPherson  Novel
# 61                John Cheever  Novel

# %% [markdown]
# ## Table 1980s to 2022

# %%
#previous: soup.select('#mw-content-text > div.mw-parser-output > table:nth-child(24)')

# %%
# previous winners = soup.select("table")[1]
# winners
# winners.select('tr td b a')[1]['title']

# %%
soup.select('mw-content-text > div.mw-parser-output > table:nth-child(27) > tbody')
# Out:
# []

# %%
winners2 = soup.select("table")[2]
#winners2

# %%
winners2.select('tr td b a')[0]['title']
# Out:
# '1979 in literature'

# %%
winners2.select('tr td b a')[1]['title']
# Out:
# "The Executioner's Song"

# %%
# Extracting year and book
titles2 = []
for name in winners2.select('tr td b a'):
    book = name.get('title')
    titles2.append(name['title'])
    
display(titles2[0:10], len(titles2))
# Out:
# ['1979 in literature',
#  "The Executioner's Song",
#  '1980 in literature',
#  'A Confederacy of Dunces',
#  '1981 in literature',
#  'Rabbit Is Rich',
#  '1982 in literature',
#  'The Color Purple',
#  '1983 in literature',
#  'Ironweed (novel)']
# 85

# %%
# Adding NaN to empty winner books

# Loop through the titles list
i = 0
while i < len(titles2)-1:
    # Check if two consecutive titles both contain the phrase 'in literature'
    if 'in literature' in titles2[i] and 'in literature' in titles2[i+1]:
        # If they do, insert a 'NaN' in between them
        titles2.insert(i+1, 'NaN')
        i += 2
    else:
        # If not, move on to the next title
        i += 1

display(titles2[0:15], len(titles2))
# Out:
# ['1979 in literature',
#  "The Executioner's Song",
#  '1980 in literature',
#  'A Confederacy of Dunces',
#  '1981 in literature',
#  'Rabbit Is Rich',
#  '1982 in literature',
#  'The Color Purple',
#  '1983 in literature',
#  'Ironweed (novel)',
#  '1984 in literature',
#  'Foreign Affairs (novel)',
#  '1985 in literature',
#  'Lonesome Dove',
#  '1986 in literature']
# 86

# %%
# Checking that there's at least one different row in between 'in literature' rows
has_different_row = False
for i in range(len(titles2)-2):
    if 'in literature' in titles2[i] and 'in literature' in titles2[i+2]:
        has_different_row = True
        break

print(has_different_row)
# Out:
# True

# %%
# Generating first dataframe

years = []
books = []

# Loop through the titles list and separate the years and book titles
for i in range(len(titles2)):
    # Every other element contains a year
    if i % 2 == 0:
        years.append(titles2[i])
    # Every other element contains a book title
    else:
        books.append(titles2[i])

# Combine the two lists into a DataFrame
pulitzer_fiction2 = pd.DataFrame({
    'year': years,
    'book': books
})

# Print the resulting DataFrame
pulitzer_fiction2.head()
# Out:
#                  year                     book
# 0  1979 in literature   The Executioner's Song
# 1  1980 in literature  A Confederacy of Dunces
# 2  1981 in literature           Rabbit Is Rich
# 3  1982 in literature         The Color Purple
# 4  1983 in literature         Ironweed (novel)

# %%
# Clean up values
pulitzer_fiction2['year'] = pulitzer_fiction2['year'].str.replace(' in literature', '')
pulitzer_fiction2['book'] = pulitzer_fiction2['book'].str.replace('\(.*\)', '', regex=True).str.strip()

#pulitzer_fiction2

# %%
# Correcting awards year

# Convert 'year' to numeric and add 1
pulitzer_fiction2['year'] = pd.to_numeric(pulitzer_fiction2['year'])
pulitzer_fiction2['year'] += 1

# display dataframe
pulitzer_fiction2.head()
# Out:
#    year                     book
# 0  1980   The Executioner's Song
# 1  1981  A Confederacy of Dunces
# 2  1982           Rabbit Is Rich
# 3  1983         The Color Purple
# 4  1984                 Ironweed

# %%
# Saving dataframe
pulitzer_fiction2.to_csv('pulitzer_fiction2.csv')

# %%
data2 = []

for winner in winners2.select('tr td'):
    for a_tag in winner.select('a'):
        if 'title' in a_tag.attrs:
            data2.append(a_tag['title'])

# %%
data2[0:20]
# Out:
# ['1979 in literature',
#  'Norman Mailer',
#  "The Executioner's Song",
#  'Little, Brown and Company',
#  'True crime',
#  'New Jersey',
#  'William Wharton (author)',
#  'Birdy (novel)',
#  'Philip Roth',
#  'The Ghost Writer',
#  '1980 in literature',
#  'John Kennedy Toole',
#  'A Confederacy of Dunces',
#  'Louisiana State University Press',
#  'Picaresque novel',
#  'Louisiana',
#  'Frederick Buechner',
#  'Godric (novel)',
#  'William Keepers Maxwell Jr.',
#  'So Long, See You Tomorrow (novel)']

# %%
# Extracting author
author2 = []
for i in range(len(data2)):
    if 'in literature' in data2[i]:
        if i+1 < len(data2) and 'in literature' not in data2[i+1]:
            author2.append(data2[i+1])
        else:
            author2.append('NaN')

# %%
author2[0:10]
# Out:
# ['Norman Mailer',
#  'John Kennedy Toole',
#  'John Updike',
#  'Alice Walker',
#  'William Kennedy (author)',
#  'Alison Lurie',
#  'Larry McMurtry',
#  'Peter Taylor (writer)',
#  'Toni Morrison',
#  'Anne Tyler']

# %%
# Add 'author' column to the dataframe and append values from 'author' list
pulitzer_fiction2['author'] = author2
pulitzer_fiction2.tail(12)
# Out:
#     year                                               book  \
# 31  2011                        A Visit from the Goon Squad
# 32  2012                                                NaN
# 33  2013                            The Orphan Master's Son
# 34  2014                                      The Goldfinch
# 35  2015                        All the Light We Cannot See
# 36  2016                                    The Sympathizer
# 37  2017                           The Underground Railroad
# 38  2018                                               Less
# 39  2019                                      The Overstory
# 40  2020                                    The Nickel Boys
# 41  2021                                 The Night Watchman
# 42  2022  The Netanyahus: An Account of a Minor and Ulti...
#
#                    author
# 31          Jennifer Egan
# 32          Karen Russell
# 33  Adam Johnson (writer)
# 34            Donna Tartt
# 35          Anthony Doerr
# 36      Viet Thanh Nguyen
# 37       Colson Whitehead
# 38      Andrew Sean Greer
# 39         Richard Powers
# 40       Colson Whitehead
# 41         Louise Erdrich
# 42  Joshua Cohen (writer)

# %%
# Correcting 2012 ('Author' value it's finalist, but there was no award)
pulitzer_fiction2.at[32, 'author'] = 'NaN'

# %%
pulitzer_fiction2.tail(12)
# Out:
#     year                                               book  \
# 31  2011                        A Visit from the Goon Squad
# 32  2012                                                NaN
# 33  2013                            The Orphan Master's Son
# 34  2014                                      The Goldfinch
# 35  2015                        All the Light We Cannot See
# 36  2016                                    The Sympathizer
# 37  2017                           The Underground Railroad
# 38  2018                                               Less
# 39  2019                                      The Overstory
# 40  2020                                    The Nickel Boys
# 41  2021                                 The Night Watchman
# 42  2022  The Netanyahus: An Account of a Minor and Ulti...
#
#                    author
# 31          Jennifer Egan
# 32                    NaN
# 33  Adam Johnson (writer)
# 34            Donna Tartt
# 35          Anthony Doerr
# 36      Viet Thanh Nguyen
# 37       Colson Whitehead
# 38      Andrew Sean Greer
# 39         Richard Powers
# 40       Colson Whitehead
# 41         Louise Erdrich
# 42  Joshua Cohen (writer)

# %%
# Extract genre
#genre = []
#for i in range(len(data2)):
#    if 'in literature' in data2[i]:
#        if i+4 < len(data2):
#            genre.append(data2[i+4])
#        else:
#            genre.append('NaN')

# %%
# Adding 'genre' column. All values are 'Novel' except rows with NaN
pulitzer_fiction2.loc[pulitzer_fiction2['author'] != 'NaN', 'genre'] = 'Novel'
pulitzer_fiction2.loc[pulitzer_fiction2['author'] == 'NaN', 'genre'] = 'NaN'

# %%
pulitzer_fiction2
# Out:
#     year                                               book  \
# 0   1980                             The Executioner's Song
# 1   1981                            A Confederacy of Dunces
# 2   1982                                     Rabbit Is Rich
# 3   1983                                   The Color Purple
# 4   1984                                           Ironweed
# 5   1985                                    Foreign Affairs
# 6   1986                                      Lonesome Dove
# 7   1987                               A Summons to Memphis
# 8   1988                                            Beloved
# 9   1989                                  Breathing Lessons
# 10  1990                 The Mambo Kings Play Songs of Love
# 11  1991                                     Rabbit At Rest
# 12  1992                                   A Thousand Acres
# 13  1993               A Good Scent from a Strange Mountain
# 14  1994                                  The Shipping News
# 15  1995                                  The Stone Diaries
# 16  1996                                   Independence Day
# 17  1997                                    Martin Dressler
# 18  1998                                  American Pastoral
# 19  1999                                          The Hours
# 20  2000                            Interpreter of Maladies
# 21  2001          The Amazing Adventures of Kavalier & Clay
# 22  2002                                       Empire Falls
# 23  2003                                          Middlesex
# 24  2004                                    The Known World
# 25  2005                                             Gilead
# 26  2006                                              March
# 27  2007                                           The Road
# 28  2008               The Brief Wondrous Life of Oscar Wao
# 29  2009                                   Olive Kitteridge
# 30  2010                                            Tinkers
# 31  2011                        A Visit from the Goon Squad
# 32  2012                                                NaN
# 33  2013                            The Orphan Master's Son
# 34  2014                                      The Goldfinch
# 35  2015                        All the Light We Cannot See
# 36  2016                                    The Sympathizer
# 37  2017                           The Underground Railroad
# 38  2018                                               Less
# 39  2019                                      The Overstory
# 40  2020                                    The Nickel Boys
# 41  2021                                 The Night Watchman
# 42  2022  The Netanyahus: An Account of a Minor and Ulti...
#
#                        author  genre
# 0               Norman Mailer  Novel
# 1          John Kennedy Toole  Novel
# 2                 John Updike  Novel
# 3                Alice Walker  Novel
# 4    William Kennedy (author)  Novel
# 5                Alison Lurie  Novel
# 6              Larry McMurtry  Novel
# 7       Peter Taylor (writer)  Novel
# 8               Toni Morrison  Novel
# 9                  Anne Tyler  Novel
# 10             Oscar Hijuelos  Novel
# 11                John Updike  Novel
# 12                Jane Smiley  Novel
# 13         Robert Olen Butler  Novel
# 14               Annie Proulx  Novel
# 15              Carol Shields  Novel
# 16               Richard Ford  Novel
# 17          Steven Millhauser  Novel
# 18                Philip Roth  Novel
# 19         Michael Cunningham  Novel
# 20              Jhumpa Lahiri  Novel
# 21             Michael Chabon  Novel
# 22              Richard Russo  Novel
# 23          Jeffrey Eugenides  Novel
# 24            Edward P. Jones  Novel
# 25         Marilynne Robinson  Novel
# 26  Geraldine Brooks (writer)  Novel
# 27            Cormac McCarthy  Novel
# 28                 Junot Díaz  Novel
# 29           Elizabeth Strout  Novel
# 30      Paul Harding (author)  Novel
# 31              Jennifer Egan  Novel
# 32                        NaN    NaN
# 33      Adam Johnson (writer)  Novel
# 34                Donna Tartt  Novel
# 35              Anthony Doerr  Novel
# 36          Viet Thanh Nguyen  Novel
# 37           Colson Whitehead  Novel
# 38          Andrew Sean Greer  Novel
# 39             Richard Powers  Novel
# 40           Colson Whitehead  Novel
# 41             Louise Erdrich  Novel
# 42      Joshua Cohen (writer)  Novel

# %% [markdown]
# ## Concatenate both dataframes

# %%
all_pulitzer_fiction_winners = pd.concat([pulitzer_fiction, pulitzer_fiction2], axis=0, ignore_index=True)

# %%
# Drop 'genre'
all_pulitzer_fiction_winners = all_pulitzer_fiction_winners.drop(['genre'],axis = 1)

# %%
all_pulitzer_fiction_winners
# Out:
#      year                                               book  \
# 0    1918                                         His Family
# 1    1919                          The Magnificent Ambersons
# 2    1920                                                NaN
# 3    1921                               The Age of Innocence
# 4    1922                                        Alice Adams
# 5    1923                                        One of Ours
# 6    1924                               The Able McLaughlins
# 7    1925                                             So Big
# 8    1926                                         Arrowsmith
# 9    1927                                       Early Autumn
# 10   1928                         The Bridge of San Luis Rey
# 11   1929                                Scarlet Sister Mary
# 12   1930                                       Laughing Boy
# 13   1931                                     Years of Grace
# 14   1932                                     The Good Earth
# 15   1933                                          The Store
# 16   1934                                  Lamb in His Bosom
# 17   1935                                    Now in November
# 18   1936                                  Honey in the Horn
# 19   1937                                 Gone with the Wind
# 20   1938                              The Late George Apley
# 21   1939                                       The Yearling
# 22   1940                                The Grapes of Wrath
# 23   1941                                                NaN
# 24   1942                                   In This Our Life
# 25   1943                                     Dragon's Teeth
# 26   1944                                Journey in the Dark
# 27   1945                                   A Bell for Adano
# 28   1946                                                NaN
# 29   1947                                 All the King's Men
# 30   1948                         Tales of the South Pacific
# 31   1949                                     Guard of Honor
# 32   1950                                       The Way West
# 33   1951                                           The Town
# 34   1952                                   The Caine Mutiny
# 35   1953                            The Old Man and the Sea
# 36   1954                                                NaN
# 37   1955                                            A Fable
# 38   1956                                      Andersonville
# 39   1957                                                NaN
# 40   1958                              A Death in the Family
# 41   1959                   The Travels of Jaimie McPheeters
# 42   1960                                 Advise and Consent
# 43   1961                              To Kill a Mockingbird
# 44   1962                                The Edge of Sadness
# 45   1963                                        The Reivers
# 46   1964                                                NaN
# 47   1965                           The Keepers of the House
# 48   1966     The Collected Stories of Katherine Anne Porter
# 49   1967                                          The Fixer
# 50   1968                      The Confessions of Nat Turner
# 51   1969                                 House Made of Dawn
# 52   1970             The Collected Stories of Jean Stafford
# 53   1971                                                NaN
# 54   1972                                    Angle of Repose
# 55   1973                            The Optimist's Daughter
# 56   1974                                                NaN
# 57   1975                                  The Killer Angels
# 58   1976                                    Humboldt's Gift
# 59   1977                                                NaN
# 60   1978                                         Elbow Room
# 61   1979                        The Stories of John Cheever
# 62   1980                             The Executioner's Song
# 63   1981                            A Confederacy of Dunces
# 64   1982                                     Rabbit Is Rich
# 65   1983                                   The Color Purple
# 66   1984                                           Ironweed
# 67   1985                                    Foreign Affairs
# 68   1986                                      Lonesome Dove
# 69   1987                               A Summons to Memphis
# 70   1988                                            Beloved
# 71   1989                                  Breathing Lessons
# 72   1990                 The Mambo Kings Play Songs of Love
# 73   1991                                     Rabbit At Rest
# 74   1992                                   A Thousand Acres
# 75   1993               A Good Scent from a Strange Mountain
# 76   1994                                  The Shipping News
# 77   1995                                  The Stone Diaries
# 78   1996                                   Independence Day
# 79   1997                                    Martin Dressler
# 80   1998                                  American Pastoral
# 81   1999                                          The Hours
# 82   2000                            Interpreter of Maladies
# 83   2001          The Amazing Adventures of Kavalier & Clay
# 84   2002                                       Empire Falls
# 85   2003                                          Middlesex
# 86   2004                                    The Known World
# 87   2005                                             Gilead
# 88   2006                                              March
# 89   2007                                           The Road
# 90   2008               The Brief Wondrous Life of Oscar Wao
# 91   2009                                   Olive Kitteridge
# 92   2010                                            Tinkers
# 93   2011                        A Visit from the Goon Squad
# 94   2012                                                NaN
# 95   2013                            The Orphan Master's Son
# 96   2014                                      The Goldfinch
# 97   2015                        All the Light We Cannot See
# 98   2016                                    The Sympathizer
# 99   2017                           The Underground Railroad
# 100  2018                                               Less
# 101  2019                                      The Overstory
# 102  2020                                    The Nickel Boys
# 103  2021                                 The Night Watchman
# 104  2022  The Netanyahus: An Account of a Minor and Ulti...
#
#                          author
# 0                  Ernest Poole
# 1              Booth Tarkington
# 2                           NaN
# 3                 Edith Wharton
# 4              Booth Tarkington
# 5                  Willa Cather
# 6    Margaret Wilson (novelist)
# 7                   Edna Ferber
# 8                Sinclair Lewis
# 9               Louis Bromfield
# 10              Thornton Wilder
# 11               Julia Peterkin
# 12              Oliver La Farge
# 13         Margaret Ayer Barnes
# 14                Pearl S. Buck
# 15              T. S. Stribling
# 16      Caroline Pafford Miller
# 17            Josephine Johnson
# 18                  H. L. Davis
# 19            Margaret Mitchell
# 20             John P. Marquand
# 21     Marjorie Kinnan Rawlings
# 22               John Steinbeck
# 23                          NaN
# 24                Ellen Glasgow
# 25               Upton Sinclair
# 26                Martin Flavin
# 27                  John Hersey
# 28                          NaN
# 29           Robert Penn Warren
# 30            James A. Michener
# 31          James Gould Cozzens
# 32            A. B. Guthrie Jr.
# 33               Conrad Richter
# 34                  Herman Wouk
# 35             Ernest Hemingway
# 36                          NaN
# 37             William Faulkner
# 38             MacKinlay Kantor
# 39                          NaN
# 40                   James Agee
# 41          Robert Lewis Taylor
# 42                  Allen Drury
# 43                   Harper Lee
# 44               Edwin O'Connor
# 45             William Faulkner
# 46                          NaN
# 47             Shirley Ann Grau
# 48        Katherine Anne Porter
# 49              Bernard Malamud
# 50               William Styron
# 51             N. Scott Momaday
# 52                Jean Stafford
# 53                          NaN
# 54              Wallace Stegner
# 55                 Eudora Welty
# 56                          NaN
# 57               Michael Shaara
# 58                  Saul Bellow
# 59                          NaN
# 60         James Alan McPherson
# 61                 John Cheever
# 62                Norman Mailer
# 63           John Kennedy Toole
# 64                  John Updike
# 65                 Alice Walker
# 66     William Kennedy (author)
# 67                 Alison Lurie
# 68               Larry McMurtry
# 69        Peter Taylor (writer)
# 70                Toni Morrison
# 71                   Anne Tyler
# 72               Oscar Hijuelos
# 73                  John Updike
# 74                  Jane Smiley
# 75           Robert Olen Butler
# 76                 Annie Proulx
# 77                Carol Shields
# 78                 Richard Ford
# 79            Steven Millhauser
# 80                  Philip Roth
# 81           Michael Cunningham
# 82                Jhumpa Lahiri
# 83               Michael Chabon
# 84                Richard Russo
# 85            Jeffrey Eugenides
# 86              Edward P. Jones
# 87           Marilynne Robinson
# 88    Geraldine Brooks (writer)
# 89              Cormac McCarthy
# 90                   Junot Díaz
# 91             Elizabeth Strout
# 92        Paul Harding (author)
# 93                Jennifer Egan
# 94                          NaN
# 95        Adam Johnson (writer)
# 96                  Donna Tartt
# 97                Anthony Doerr
# 98            Viet Thanh Nguyen
# 99             Colson Whitehead
# 100           Andrew Sean Greer
# 101              Richard Powers
# 102            Colson Whitehead
# 103              Louise Erdrich
# 104       Joshua Cohen (writer)

# %%
# Delete '(any text)' from author's name in 'authors' column
import re

all_pulitzer_fiction_winners['author'] = all_pulitzer_fiction_winners['author'].apply(lambda x: re.sub(r'\([^()]*\)', '', x).strip())

# %%
# NaN was string..
import numpy as np
all_pulitzer_fiction_winners = all_pulitzer_fiction_winners.replace("NaN", np.nan)

# %%
all_pulitzer_fiction_winners.isna()
# Out:
#       year   book  author
# 0    False  False   False
# 1    False  False   False
# 2    False   True    True
# 3    False  False   False
# 4    False  False   False
# 5    False  False   False
# 6    False  False   False
# 7    False  False   False
# 8    False  False   False
# 9    False  False   False
# 10   False  False   False
# 11   False  False   False
# 12   False  False   False
# 13   False  False   False
# 14   False  False   False
# 15   False  False   False
# 16   False  False   False
# 17   False  False   False
# 18   False  False   False
# 19   False  False   False
# 20   False  False   False
# 21   False  False   False
# 22   False  False   False
# 23   False   True    True
# 24   False  False   False
# 25   False  False   False
# 26   False  False   False
# 27   False  False   False
# 28   False   True    True
# 29   False  False   False
# 30   False  False   False
# 31   False  False   False
# 32   False  False   False
# 33   False  False   False
# 34   False  False   False
# 35   False  False   False
# 36   False   True    True
# 37   False  False   False
# 38   False  False   False
# 39   False   True    True
# 40   False  False   False
# 41   False  False   False
# 42   False  False   False
# 43   False  False   False
# 44   False  False   False
# 45   False  False   False
# 46   False   True    True
# 47   False  False   False
# 48   False  False   False
# 49   False  False   False
# 50   False  False   False
# 51   False  False   False
# 52   False  False   False
# 53   False   True    True
# 54   False  False   False
# 55   False  False   False
# 56   False   True    True
# 57   False  False   False
# 58   False  False   False
# 59   False   True    True
# 60   False  False   False
# 61   False  False   False
# 62   False  False   False
# 63   False  False   False
# 64   False  False   False
# 65   False  False   False
# 66   False  False   False
# 67   False  False   False
# 68   False  False   False
# 69   False  False   False
# 70   False  False   False
# 71   False  False   False
# 72   False  False   False
# 73   False  False   False
# 74   False  False   False
# 75   False  False   False
# 76   False  False   False
# 77   False  False   False
# 78   False  False   False
# 79   False  False   False
# 80   False  False   False
# 81   False  False   False
# 82   False  False   False
# 83   False  False   False
# 84   False  False   False
# 85   False  False   False
# 86   False  False   False
# 87   False  False   False
# 88   False  False   False
# 89   False  False   False
# 90   False  False   False
# 91   False  False   False
# 92   False  False   False
# 93   False  False   False
# 94   False   True    True
# 95   False  False   False
# 96   False  False   False
# 97   False  False   False
# 98   False  False   False
# 99   False  False   False
# 100  False  False   False
# 101  False  False   False
# 102  False  False   False
# 103  False  False   False
# 104  False  False   False

# %%
# Replace NaN values for 'None awarded'
all_pulitzer_fiction_winners['book'] = all_pulitzer_fiction_winners['book'].fillna('None awarded')
all_pulitzer_fiction_winners['author'] = all_pulitzer_fiction_winners['author'].fillna('None awarded')

# %%
all_pulitzer_fiction_winners
# Out:
#      year                                               book  \
# 0    1918                                         His Family
# 1    1919                          The Magnificent Ambersons
# 2    1920                                       None awarded
# 3    1921                               The Age of Innocence
# 4    1922                                        Alice Adams
# 5    1923                                        One of Ours
# 6    1924                               The Able McLaughlins
# 7    1925                                             So Big
# 8    1926                                         Arrowsmith
# 9    1927                                       Early Autumn
# 10   1928                         The Bridge of San Luis Rey
# 11   1929                                Scarlet Sister Mary
# 12   1930                                       Laughing Boy
# 13   1931                                     Years of Grace
# 14   1932                                     The Good Earth
# 15   1933                                          The Store
# 16   1934                                  Lamb in His Bosom
# 17   1935                                    Now in November
# 18   1936                                  Honey in the Horn
# 19   1937                                 Gone with the Wind
# 20   1938                              The Late George Apley
# 21   1939                                       The Yearling
# 22   1940                                The Grapes of Wrath
# 23   1941                                       None awarded
# 24   1942                                   In This Our Life
# 25   1943                                     Dragon's Teeth
# 26   1944                                Journey in the Dark
# 27   1945                                   A Bell for Adano
# 28   1946                                       None awarded
# 29   1947                                 All the King's Men
# 30   1948                         Tales of the South Pacific
# 31   1949                                     Guard of Honor
# 32   1950                                       The Way West
# 33   1951                                           The Town
# 34   1952                                   The Caine Mutiny
# 35   1953                            The Old Man and the Sea
# 36   1954                                       None awarded
# 37   1955                                            A Fable
# 38   1956                                      Andersonville
# 39   1957                                       None awarded
# 40   1958                              A Death in the Family
# 41   1959                   The Travels of Jaimie McPheeters
# 42   1960                                 Advise and Consent
# 43   1961                              To Kill a Mockingbird
# 44   1962                                The Edge of Sadness
# 45   1963                                        The Reivers
# 46   1964                                       None awarded
# 47   1965                           The Keepers of the House
# 48   1966     The Collected Stories of Katherine Anne Porter
# 49   1967                                          The Fixer
# 50   1968                      The Confessions of Nat Turner
# 51   1969                                 House Made of Dawn
# 52   1970             The Collected Stories of Jean Stafford
# 53   1971                                       None awarded
# 54   1972                                    Angle of Repose
# 55   1973                            The Optimist's Daughter
# 56   1974                                       None awarded
# 57   1975                                  The Killer Angels
# 58   1976                                    Humboldt's Gift
# 59   1977                                       None awarded
# 60   1978                                         Elbow Room
# 61   1979                        The Stories of John Cheever
# 62   1980                             The Executioner's Song
# 63   1981                            A Confederacy of Dunces
# 64   1982                                     Rabbit Is Rich
# 65   1983                                   The Color Purple
# 66   1984                                           Ironweed
# 67   1985                                    Foreign Affairs
# 68   1986                                      Lonesome Dove
# 69   1987                               A Summons to Memphis
# 70   1988                                            Beloved
# 71   1989                                  Breathing Lessons
# 72   1990                 The Mambo Kings Play Songs of Love
# 73   1991                                     Rabbit At Rest
# 74   1992                                   A Thousand Acres
# 75   1993               A Good Scent from a Strange Mountain
# 76   1994                                  The Shipping News
# 77   1995                                  The Stone Diaries
# 78   1996                                   Independence Day
# 79   1997                                    Martin Dressler
# 80   1998                                  American Pastoral
# 81   1999                                          The Hours
# 82   2000                            Interpreter of Maladies
# 83   2001          The Amazing Adventures of Kavalier & Clay
# 84   2002                                       Empire Falls
# 85   2003                                          Middlesex
# 86   2004                                    The Known World
# 87   2005                                             Gilead
# 88   2006                                              March
# 89   2007                                           The Road
# 90   2008               The Brief Wondrous Life of Oscar Wao
# 91   2009                                   Olive Kitteridge
# 92   2010                                            Tinkers
# 93   2011                        A Visit from the Goon Squad
# 94   2012                                       None awarded
# 95   2013                            The Orphan Master's Son
# 96   2014                                      The Goldfinch
# 97   2015                        All the Light We Cannot See
# 98   2016                                    The Sympathizer
# 99   2017                           The Underground Railroad
# 100  2018                                               Less
# 101  2019                                      The Overstory
# 102  2020                                    The Nickel Boys
# 103  2021                                 The Night Watchman
# 104  2022  The Netanyahus: An Account of a Minor and Ulti...
#
#                        author
# 0                Ernest Poole
# 1            Booth Tarkington
# 2                None awarded
# 3               Edith Wharton
# 4            Booth Tarkington
# 5                Willa Cather
# 6             Margaret Wilson
# 7                 Edna Ferber
# 8              Sinclair Lewis
# 9             Louis Bromfield
# 10            Thornton Wilder
# 11             Julia Peterkin
# 12            Oliver La Farge
# 13       Margaret Ayer Barnes
# 14              Pearl S. Buck
# 15            T. S. Stribling
# 16    Caroline Pafford Miller
# 17          Josephine Johnson
# 18                H. L. Davis
# 19          Margaret Mitchell
# 20           John P. Marquand
# 21   Marjorie Kinnan Rawlings
# 22             John Steinbeck
# 23               None awarded
# 24              Ellen Glasgow
# 25             Upton Sinclair
# 26              Martin Flavin
# 27                John Hersey
# 28               None awarded
# 29         Robert Penn Warren
# 30          James A. Michener
# 31        James Gould Cozzens
# 32          A. B. Guthrie Jr.
# 33             Conrad Richter
# 34                Herman Wouk
# 35           Ernest Hemingway
# 36               None awarded
# 37           William Faulkner
# 38           MacKinlay Kantor
# 39               None awarded
# 40                 James Agee
# 41        Robert Lewis Taylor
# 42                Allen Drury
# 43                 Harper Lee
# 44             Edwin O'Connor
# 45           William Faulkner
# 46               None awarded
# 47           Shirley Ann Grau
# 48      Katherine Anne Porter
# 49            Bernard Malamud
# 50             William Styron
# 51           N. Scott Momaday
# 52              Jean Stafford
# 53               None awarded
# 54            Wallace Stegner
# 55               Eudora Welty
# 56               None awarded
# 57             Michael Shaara
# 58                Saul Bellow
# 59               None awarded
# 60       James Alan McPherson
# 61               John Cheever
# 62              Norman Mailer
# 63         John Kennedy Toole
# 64                John Updike
# 65               Alice Walker
# 66            William Kennedy
# 67               Alison Lurie
# 68             Larry McMurtry
# 69               Peter Taylor
# 70              Toni Morrison
# 71                 Anne Tyler
# 72             Oscar Hijuelos
# 73                John Updike
# 74                Jane Smiley
# 75         Robert Olen Butler
# 76               Annie Proulx
# 77              Carol Shields
# 78               Richard Ford
# 79          Steven Millhauser
# 80                Philip Roth
# 81         Michael Cunningham
# 82              Jhumpa Lahiri
# 83             Michael Chabon
# 84              Richard Russo
# 85          Jeffrey Eugenides
# 86            Edward P. Jones
# 87         Marilynne Robinson
# 88           Geraldine Brooks
# 89            Cormac McCarthy
# 90                 Junot Díaz
# 91           Elizabeth Strout
# 92               Paul Harding
# 93              Jennifer Egan
# 94               None awarded
# 95               Adam Johnson
# 96                Donna Tartt
# 97              Anthony Doerr
# 98          Viet Thanh Nguyen
# 99           Colson Whitehead
# 100         Andrew Sean Greer
# 101            Richard Powers
# 102          Colson Whitehead
# 103            Louise Erdrich
# 104              Joshua Cohen

# %%
all_pulitzer_fiction_winners.tail(10)
# Out:
#      year                                               book  \
# 95   2013                            The Orphan Master's Son
# 96   2014                                      The Goldfinch
# 97   2015                        All the Light We Cannot See
# 98   2016                                    The Sympathizer
# 99   2017                           The Underground Railroad
# 100  2018                                               Less
# 101  2019                                      The Overstory
# 102  2020                                    The Nickel Boys
# 103  2021                                 The Night Watchman
# 104  2022  The Netanyahus: An Account of a Minor and Ulti...
#
#                 author
# 95        Adam Johnson
# 96         Donna Tartt
# 97       Anthony Doerr
# 98   Viet Thanh Nguyen
# 99    Colson Whitehead
# 100  Andrew Sean Greer
# 101     Richard Powers
# 102   Colson Whitehead
# 103     Louise Erdrich
# 104       Joshua Cohen

# %% [markdown]
# ## URL

# %%
# URL example
# https://www.pulitzer.org/winners/joshua-cohen

# %%
# create a new list to store the URLs
url_list = []

# iterate through the authors and get their Pulitzer page URLs
for author in all_pulitzer_fiction_winners['author']:
    if author == 'None awarded':
        url_list.append('None awarded')
    else:
        author_url = 'https://www.pulitzer.org/winners/' + '-'.join(author.lower().split())
        author_url = author_url.strip()
        url_list.append(author_url)

# %%
url_list[:10]
# Out:
# ['https://www.pulitzer.org/winners/ernest-poole',
#  'https://www.pulitzer.org/winners/booth-tarkington',
#  'None awarded',
#  'https://www.pulitzer.org/winners/edith-wharton',
#  'https://www.pulitzer.org/winners/booth-tarkington',
#  'https://www.pulitzer.org/winners/willa-cather',
#  'https://www.pulitzer.org/winners/margaret-wilson',
#  'https://www.pulitzer.org/winners/edna-ferber',
#  'https://www.pulitzer.org/winners/sinclair-lewis',
#  'https://www.pulitzer.org/winners/louis-bromfield']

# %%
# Add the URLs as a new column in the main dataframe
all_pulitzer_fiction_winners['URL'] = url_list

# %%
pd.set_option('display.max_rows', None)
all_pulitzer_fiction_winners.tail(60)
# Out:
#      year                                               book  \
# 45   1963                                        The Reivers
# 46   1964                                       None awarded
# 47   1965                           The Keepers of the House
# 48   1966     The Collected Stories of Katherine Anne Porter
# 49   1967                                          The Fixer
# 50   1968                      The Confessions of Nat Turner
# 51   1969                                 House Made of Dawn
# 52   1970             The Collected Stories of Jean Stafford
# 53   1971                                       None awarded
# 54   1972                                    Angle of Repose
# 55   1973                            The Optimist's Daughter
# 56   1974                                       None awarded
# 57   1975                                  The Killer Angels
# 58   1976                                    Humboldt's Gift
# 59   1977                                       None awarded
# 60   1978                                         Elbow Room
# 61   1979                        The Stories of John Cheever
# 62   1980                             The Executioner's Song
# 63   1981                            A Confederacy of Dunces
# 64   1982                                     Rabbit Is Rich
# 65   1983                                   The Color Purple
# 66   1984                                           Ironweed
# 67   1985                                    Foreign Affairs
# 68   1986                                      Lonesome Dove
# 69   1987                               A Summons to Memphis
# 70   1988                                            Beloved
# 71   1989                                  Breathing Lessons
# 72   1990                 The Mambo Kings Play Songs of Love
# 73   1991                                     Rabbit At Rest
# 74   1992                                   A Thousand Acres
# 75   1993               A Good Scent from a Strange Mountain
# 76   1994                                  The Shipping News
# 77   1995                                  The Stone Diaries
# 78   1996                                   Independence Day
# 79   1997                                    Martin Dressler
# 80   1998                                  American Pastoral
# 81   1999                                          The Hours
# 82   2000                            Interpreter of Maladies
# 83   2001          The Amazing Adventures of Kavalier & Clay
# 84   2002                                       Empire Falls
# 85   2003                                          Middlesex
# 86   2004                                    The Known World
# 87   2005                                             Gilead
# 88   2006                                              March
# 89   2007                                           The Road
# 90   2008               The Brief Wondrous Life of Oscar Wao
# 91   2009                                   Olive Kitteridge
# 92   2010                                            Tinkers
# 93   2011                        A Visit from the Goon Squad
# 94   2012                                       None awarded
# 95   2013                            The Orphan Master's Son
# 96   2014                                      The Goldfinch
# 97   2015                        All the Light We Cannot See
# 98   2016                                    The Sympathizer
# 99   2017                           The Underground Railroad
# 100  2018                                               Less
# 101  2019                                      The Overstory
# 102  2020                                    The Nickel Boys
# 103  2021                                 The Night Watchman
# 104  2022  The Netanyahus: An Account of a Minor and Ulti...
#
#                     author                                                URL
# 45        William Faulkner  https://www.pulitzer.org/winners/william-faulkner
# 46            None awarded                                       None awarded
# 47        Shirley Ann Grau  https://www.pulitzer.org/winners/shirley-ann-grau
# 48   Katherine Anne Porter  https://www.pulitzer.org/winners/katherine-ann...
# 49         Bernard Malamud   https://www.pulitzer.org/winners/bernard-malamud
# 50          William Styron    https://www.pulitzer.org/winners/william-styron
# 51        N. Scott Momaday  https://www.pulitzer.org/winners/n.-scott-momaday
# 52           Jean Stafford     https://www.pulitzer.org/winners/jean-stafford
# 53            None awarded                                       None awarded
# 54         Wallace Stegner   https://www.pulitzer.org/winners/wallace-stegner
# 55            Eudora Welty      https://www.pulitzer.org/winners/eudora-welty
# 56            None awarded                                       None awarded
# 57          Michael Shaara    https://www.pulitzer.org/winners/michael-shaara
# 58             Saul Bellow       https://www.pulitzer.org/winners/saul-bellow
# 59            None awarded                                       None awarded
# 60    James Alan McPherson  https://www.pulitzer.org/winners/james-alan-mc...
# 61            John Cheever      https://www.pulitzer.org/winners/john-cheever
# 62           Norman Mailer     https://www.pulitzer.org/winners/norman-mailer
# 63      John Kennedy Toole  https://www.pulitzer.org/winners/john-kennedy-...
# 64             John Updike       https://www.pulitzer.org/winners/john-updike
# 65            Alice Walker      https://www.pulitzer.org/winners/alice-walker
# 66         William Kennedy   https://www.pulitzer.org/winners/william-kennedy
# 67            Alison Lurie      https://www.pulitzer.org/winners/alison-lurie
# 68          Larry McMurtry    https://www.pulitzer.org/winners/larry-mcmurtry
# 69            Peter Taylor      https://www.pulitzer.org/winners/peter-taylor
# 70           Toni Morrison     https://www.pulitzer.org/winners/toni-morrison
# 71              Anne Tyler        https://www.pulitzer.org/winners/anne-tyler
# 72          Oscar Hijuelos    https://www.pulitzer.org/winners/oscar-hijuelos
# 73             John Updike       https://www.pulitzer.org/winners/john-updike
# 74             Jane Smiley       https://www.pulitzer.org/winners/jane-smiley
# 75      Robert Olen Butler  https://www.pulitzer.org/winners/robert-olen-b...
# 76            Annie Proulx      https://www.pulitzer.org/winners/annie-proulx
# 77           Carol Shields     https://www.pulitzer.org/winners/carol-shields
# 78            Richard Ford      https://www.pulitzer.org/winners/richard-ford
# 79       Steven Millhauser  https://www.pulitzer.org/winners/steven-millha...
# 80             Philip Roth       https://www.pulitzer.org/winners/philip-roth
# 81      Michael Cunningham  https://www.pulitzer.org/winners/michael-cunni...
# 82           Jhumpa Lahiri     https://www.pulitzer.org/winners/jhumpa-lahiri
# 83          Michael Chabon    https://www.pulitzer.org/winners/michael-chabon
# 84           Richard Russo     https://www.pulitzer.org/winners/richard-russo
# 85       Jeffrey Eugenides  https://www.pulitzer.org/winners/jeffrey-eugen...
# 86         Edward P. Jones   https://www.pulitzer.org/winners/edward-p.-jones
# 87      Marilynne Robinson  https://www.pulitzer.org/winners/marilynne-rob...
# 88        Geraldine Brooks  https://www.pulitzer.org/winners/geraldine-brooks
# 89         Cormac McCarthy   https://www.pulitzer.org/winners/cormac-mccarthy
# 90              Junot Díaz        https://www.pulitzer.org/winners/junot-díaz
# 91        Elizabeth Strout  https://www.pulitzer.org/winners/elizabeth-strout
# 92            Paul Harding      https://www.pulitzer.org/winners/paul-harding
# 93           Jennifer Egan     https://www.pulitzer.org/winners/jennifer-egan
# 94            None awarded                                       None awarded
# 95            Adam Johnson      https://www.pulitzer.org/winners/adam-johnson
# 96             Donna Tartt       https://www.pulitzer.org/winners/donna-tartt
# 97           Anthony Doerr     https://www.pulitzer.org/winners/anthony-doerr
# 98       Viet Thanh Nguyen  https://www.pulitzer.org/winners/viet-thanh-ng...
# 99        Colson Whitehead  https://www.pulitzer.org/winners/colson-whitehead
# 100      Andrew Sean Greer  https://www.pulitzer.org/winners/andrew-sean-g...
# 101         Richard Powers    https://www.pulitzer.org/winners/richard-powers
# 102       Colson Whitehead  https://www.pulitzer.org/winners/colson-whitehead
# 103         Louise Erdrich    https://www.pulitzer.org/winners/louise-erdrich
# 104           Joshua Cohen      https://www.pulitzer.org/winners/joshua-cohen

# %% [markdown]
# ## Save to csv

# %%
all_pulitzer_fiction_winners.to_csv('pulitzer_fiction_winners_WEB_SCRAPING.csv')
